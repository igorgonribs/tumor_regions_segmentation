# %% [markdown]
# # Instanciate the 'train', 'valid', and 'test' dataloaders

# %%
from bones_dataloader import *

dataset_dir = "../../datasets/BONE_CHANNELS"

batch_size = 6
patch_size = (640, 640)
color_model = "RGB"
dataloaders = create_dataloader(tile_size="{}x{}".format(patch_size[0], patch_size[1]),
                                batch_size=batch_size, 
                                shuffle=True,
                                img_input_size=patch_size,
                                img_output_size=patch_size,
                                dataset_dir=dataset_dir,
                                color_model=color_model,
                                augmentation_strategy="random",
                                start_epoch=1,
                                validation_split=0.2)

dataset_train_size = len(dataloaders['train'].dataset)
dataset_test_size = len(dataloaders['test'].dataset)
# Out:
# 2023-04-22 18:11:12,466 :: INFO load_dataset :: [training] ../../datasets/BONE_CHANNELS/training
# 2023-04-22 18:11:12,469 :: INFO load_dataset :: [training] ../../datasets/BONE_CHANNELS/training
# 2023-04-22 18:11:12,470 :: INFO load_dataset :: [testing] ../../datasets/BONE_CHANNELS/testing
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 8
#       6 patch_size = (640, 640)
#       7 color_model = "RGB"
# ----> 8 dataloaders = create_dataloader(tile_size="{}x{}".format(patch_size[0], patch_size[1]),
#       9                                 batch_size=batch_size,
#      10                                 shuffle=True,
#      11                                 img_input_size=patch_size,
#      12                                 img_output_size=patch_size,
#      13                                 dataset_dir=dataset_dir,
#      14                                 color_model=color_model,
#      15                                 augmentation_strategy="random",
#      16                                 start_epoch=1,
#      17                                 validation_split=0.2)
#      19 dataset_train_size = len(dataloaders['train'].dataset)
#      20 dataset_test_size = len(dataloaders['test'].dataset)
#
# File C:\Igor\dali\tumor_regions_segmentation-main\sourcecode\BONE_CHANNELS\bones_dataloader.py:186, in create_dataloader(tile_size, batch_size, shuffle, img_input_size, img_output_size, dataset_dir, color_model, augmentation, augmentation_strategy, start_epoch, validation_split)
#     177 image_datasets = {x: BONE_CHANNELSDataset(img_dir=dataset_dir,
#     178                                  img_input_size=img_input_size, img_output_size=img_output_size,
#     179                                  dataset_type='testing' if x == 'test' else 'training',
#    (...)
#     182                                  color_model=color_model,
#     183                                  start_epoch=start_epoch) for x in ['train', 'valid', 'test']}
#     184 if validation_split > 0:
# --> 186     train_dataset_index, valid_dataset_index = train_test_split(range(len(image_datasets['train'])),
#     187                                                                 test_size=validation_split, random_state=0)
#     188     train_dataset_index.sort()
#     189     valid_dataset_index.sort()
#
# File C:\Igor\Anaconda\envs\dali\lib\site-packages\sklearn\model_selection\_split.py:2562, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2559 arrays = indexable(*arrays)
#    2561 n_samples = _num_samples(arrays[0])
# -> 2562 n_train, n_test = _validate_shuffle_split(
#    2563     n_samples, test_size, train_size, default_test_size=0.25
#    2564 )
#    2566 if shuffle is False:
#    2567     if stratify is not None:
#
# File C:\Igor\Anaconda\envs\dali\lib\site-packages\sklearn\model_selection\_split.py:2236, in _validate_shuffle_split(n_samples, test_size, train_size, default_test_size)
#    2233 n_train, n_test = int(n_train), int(n_test)
#    2235 if n_train == 0:
# -> 2236     raise ValueError(
#    2237         "With n_samples={}, test_size={} and train_size={}, the "
#    2238         "resulting train set will be empty. Adjust any of the "
#    2239         "aforementioned parameters.".format(n_samples, test_size, train_size)
#    2240     )
#    2242 return n_train, n_test
#
# ValueError: With n_samples=0, test_size=0.2 and train_size=None, the resulting train set will be empty. Adjust any of the aforementioned parameters.

# %% [markdown]
# ### Show some train images

# %%
dataset_show(dataloaders['train'], batch_size=batch_size, show_masks=True, row_limit=1)

# %% [markdown]
# ### Show some validation images

# %%
dataset_show(dataloaders['valid'], batch_size=batch_size, show_masks=True, row_limit=1)

# %% [markdown]
# ### Show some test images

# %%
dataset_show(dataloaders['test'], batch_size=batch_size, show_masks=True, row_limit=1)

# %% [markdown]
# # Instanciate the 'train', 'valid', and 'test' dataloaders for 512x512 version

# %%
from bones_dataloader_512x512 import *

dataset_dir = "../../datasets/BONE_CHANNELS_reduced_size"

batch_size = 6
color_model = "RGB"
dataloaders = create_dataloader(batch_size=batch_size, 
                                shuffle=True,
                                dataset_dir=dataset_dir,
                                color_model=color_model,
                                augmentation_strategy="random",
                                start_epoch=1,
                                validation_split=0.2)

dataset_train_size = len(dataloaders['train'].dataset)
dataset_test_size = len(dataloaders['test'].dataset)
# Out:
# 2023-04-22 18:11:23,481 :: INFO load_dataset :: [training] ../../datasets/BONE_CHANNELS_reduced_size/training
# 2023-04-22 18:11:23,483 :: INFO load_dataset :: [training] ../../datasets/BONE_CHANNELS_reduced_size/training
# 2023-04-22 18:11:23,486 :: INFO load_dataset :: [testing] ../../datasets/BONE_CHANNELS_reduced_size/testing
# 2023-04-22 18:11:23,489 :: INFO create_dataloader :: Train images (512x512): 7 augmentation: random
# 2023-04-22 18:11:23,490 :: INFO create_dataloader :: Valid images (512x512): 2 augmentation: no_augmentation
# 2023-04-22 18:11:23,491 :: INFO create_dataloader :: Test images (512x512): 9 augmentation: no_augmentation

# %% [markdown]
# # Show some train images

# %%
dataset_show(dataloaders['train'], batch_size=batch_size, show_masks=True, row_limit=1)
# Out:
# 2023-04-22 18:11:29,705 :: INFO transform :: Epoch: '1' augmentation random None
# 2023-04-22 18:11:30,393 :: INFO dataset_show :: Batch 1: 6/7 images torch.Size([6, 3, 512, 512]) masks torch.Size([6, 512, 512])

# %% [markdown]
# # Show some validation images

# %%
dataset_show(dataloaders['valid'], batch_size=batch_size, show_masks=True, row_limit=1)

# %% [markdown]
# # Show some test images

# %%
dataset_show(dataloaders['test'], batch_size=batch_size, show_masks=True, row_limit=1)
# Out:
# 2023-04-22 18:11:38,789 :: INFO transform :: Epoch: '1' augmentation no_augmentation None
# 2023-04-22 18:11:39,382 :: INFO dataset_show :: Batch 1: 6/9 images torch.Size([6, 3, 512, 512]) masks torch.Size([6, 512, 512])
