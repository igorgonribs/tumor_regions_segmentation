# %% [markdown]
# # Instanciate the 'train', 'valid', and 'test' dataloaders

# %%
from bones_dataloader import *

dataset_dir = "../../datasets/BONE_CHANNELS"

batch_size = 6
patch_size = (640, 640)
color_model = "RGB"

dataloaders = create_dataloader(tile_size="{}x{}".format(patch_size[0], patch_size[1]),
                                batch_size=batch_size, 
                                shuffle=True,
                                img_input_size=patch_size,
                                img_output_size=patch_size,
                                dataset_dir=dataset_dir,
                                color_model=color_model,
                                augmentation_strategy="random",
                                start_epoch=1,
                                validation_split=0.2)

dataset_train_size = len(dataloaders['train'].dataset)
dataset_test_size = len(dataloaders['test'].dataset)

logger.info(dataset_test_size)
logger.info(dataset_train_size)
# Out:
# 2023-06-18 17:43:23,777 :: INFO load_dataset :: [training] ../../datasets/BONE_CHANNELS/training
# 2023-06-18 17:43:23,787 :: INFO load_dataset :: [training] ../../datasets/BONE_CHANNELS/training
# 2023-06-18 17:43:23,798 :: INFO load_dataset :: [testing] ../../datasets/BONE_CHANNELS/testing
# 2023-06-18 17:43:23,809 :: INFO create_dataloader :: Train images (640x640): 182 augmentation: random
# 2023-06-18 17:43:23,810 :: INFO create_dataloader :: Valid images (640x640): 46 augmentation: no_augmentation
# 2023-06-18 17:43:23,810 :: INFO create_dataloader :: Test images (640x640): 228 augmentation: no_augmentation
# 2023-06-18 17:43:23,811 :: INFO <module> :: 228
# 2023-06-18 17:43:23,812 :: INFO <module> :: 182

# %% [markdown]
# ### Show some train images

# %%
dataset_show(dataloaders['train'], batch_size=batch_size, show_masks=True, row_limit=1)
# Out:
# 2023-06-18 17:43:36,697 :: INFO transform :: Epoch: '1' augmentation random None
# 2023-06-18 17:43:36,906 :: INFO dataset_show :: Batch 1: 6/182 images torch.Size([6, 3, 640, 640]) masks torch.Size([6, 640, 640])

# %% [markdown]
# ### Show some validation images

# %%
dataset_show(dataloaders['valid'], batch_size=batch_size, show_masks=True, row_limit=1)
# Out:
# 2023-06-18 17:43:49,440 :: INFO transform :: Epoch: '1' augmentation no_augmentation None
# 2023-06-18 17:43:49,635 :: INFO dataset_show :: Batch 1: 6/46 images torch.Size([6, 3, 640, 640]) masks torch.Size([6, 640, 640])

# %% [markdown]
# ### Show some test images

# %%
dataset_show(dataloaders['test'], batch_size=batch_size, show_masks=True, row_limit=1)
# Out:
# 2023-04-24 18:05:25,482 :: INFO transform :: Epoch: '1' augmentation no_augmentation None
# 2023-04-24 18:05:25,724 :: INFO dataset_show :: Batch 1: 6/7 images torch.Size([6, 3, 512, 512]) masks torch.Size([6, 512, 512])

# %% [markdown]
# # Instanciate the 'train', 'valid', and 'test' dataloaders for 512x512 version

# %%
from bones_dataloader_512x512 import *

dataset_dir = "../../datasets/BONE_CHANNELS_reduced_size"

batch_size = 6
color_model = "RGB"
dataloaders = create_dataloader(batch_size=batch_size, 
                                shuffle=True,
                                dataset_dir=dataset_dir,
                                color_model=color_model,
                                augmentation_strategy="random",
                                start_epoch=1,
                                validation_split=0.2)

dataset_train_size = len(dataloaders['train'].dataset)
dataset_test_size = len(dataloaders['test'].dataset)

# %% [markdown]
# # Show some train images

# %%
dataset_show(dataloaders['train'], batch_size=batch_size, show_masks=True, row_limit=1)

# %% [markdown]
# # Show some validation images

# %%
dataset_show(dataloaders['valid'], batch_size=batch_size, show_masks=True, row_limit=1)

# %% [markdown]
# # Show some test images

# %%
dataset_show(dataloaders['test'], batch_size=batch_size, show_masks=True, row_limit=1)
