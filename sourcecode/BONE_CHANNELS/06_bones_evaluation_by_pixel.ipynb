# %% [markdown]
# # Quantitative metrics for image-patches

# %%
import os
import sys
import csv

from scipy import ndimage as nd
from skimage import measure



current_path = os.path.abspath('.')
root_path = os.path.dirname(os.path.dirname(current_path))
sys.path.append(root_path)

from sourcecode.BONE_CHANNELS.bones_dataloader import *
from sourcecode.wsi_image_utils import *
from sourcecode.evaluation_utils import *

number_epoches = 100
dataset_name = "BONE_CHANNELS"
dataset_dir = "../../datasets/" + dataset_name
batch_size = 1
patch_size = 640
patch_size_tuple = (patch_size, patch_size)
color_model = "LAB"
class_name = "bones"
dataloaders = create_dataloader(tile_size="{}x{}".format(patch_size, patch_size),
                                batch_size=batch_size, 
                                shuffle=False,
                                img_input_size=patch_size_tuple,
                                img_output_size=patch_size_tuple,
                                dataset_dir=dataset_dir,
                                color_model=color_model)

dataset_train_size = len(dataloaders['train'].dataset)
dataset_test_size = len(dataloaders['test'].dataset)
print("-")

tile_size = 20
magnification=0.625

threshold_itc = 200/(0.243 * pow(2, 5))

#wsi_images_dir_normal = "{}/testing/normal/wsi".format(dataset_dir)
wsi_images_dir_tumor = "{}/testing/bones".format(dataset_dir)

trained_model_version = f"TL_{dataset_name}__Size-{patch_size}x{patch_size}_Epoch-{number_epoches}_Images-{dataset_test_size}_Batch-1__random_distortion"
results_dir="{}/results/{}/testing".format(dataset_dir, trained_model_version)

# Arquivo com as métricas médias para cada p
csv_mean_file_path = "{}/pixels/mean_quantitative_analysis.csv".format(results_dir)
mean_file = open(csv_mean_file_path, newline='', mode='w')
mean_writer = csv.writer(mean_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
mean_writer.writerow(['wsi_image', 'class', 'mean auc', 'mean accuracy', 'mean precision', 'mean f1/dice', 'mean jaccard', 'mean sensitivity/recall', 'mean specificity', 'mean tp', 'mean tn', 'mean fp', 'mean fn'])

wsi_tissue_patches = {}
# Out:
# 2024-06-03 10:17:50,768 :: INFO load_dataset :: [training] ../../datasets/BONE_CHANNELS/training
# 2024-06-03 10:17:50,852 :: INFO load_dataset :: [training] ../../datasets/BONE_CHANNELS/training
# 2024-06-03 10:17:50,932 :: INFO load_dataset :: [testing] ../../datasets/BONE_CHANNELS/testing
# 2024-06-03 10:17:50,958 :: INFO create_dataloader :: Train images (640x640): 1573 augmentation: random
# 2024-06-03 10:17:50,959 :: INFO create_dataloader :: Test images (640x640): 464 augmentation: no_augmentation
# -

# %%
import numpy as np
from PIL import Image
from scipy import ndimage
from skimage.measure import regionprops
import os
import matplotlib.pyplot as plt

def fill_contours(arr):
    return np.maximum.accumulate(arr,1) & np.maximum.accumulate(arr[:,::-1],1)[:,::-1]

def get_mean_props_area(RGBna):
    labeled, nr_objects = ndimage.label(RGBna != 0.) 
    props = regionprops(labeled)

    if nr_objects == 0:
        return 0
    
    mean_props_area = 0
    for prop in range(len(props)):
        mean_props_area = mean_props_area + props[prop].area
    
    mean_props_area = mean_props_area/len(props)
    return mean_props_area

# Remove ruídos  
def remove_noise(RGBna, mean_props_area):
    labeled, _ = ndimage.label(RGBna != 0.) 
    props = regionprops(labeled)

    new_mask = np.copy(RGBna)
    
    for prop in range(len(props)):
        if props[prop].area > (0.1)*mean_props_area:
            continue
        else:
            [X, Y, x, y] = props[prop].bbox
            new_mask[X:x, Y:y] = props[prop].image_filled.astype(np.uint8)*0
       
            
    #plt.imshow(new_mask)#Image.fromarray(new_mask).show()
    return new_mask

# Preenche contornos  
def fill_components_contours(RGBna):
    labeled, nr_objects = ndimage.label(RGBna != 0.) 
    props = regionprops(labeled)

    new_mask = np.copy(RGBna)

    for prop in range(len(props)):
        [X, Y, x, y] = props[prop].bbox
        new_mask[X:x, Y:y] = fill_contours(props[prop].image_filled.astype(np.uint8)*255)

    return new_mask

# %% [markdown]
# ## Evaluation varying p

# %%
for threshold_prob in np.arange(0.0,1.0,0.05):
    csv_file_path = f'{results_dir}/pixels/quantitative_analysis_{"%.3f" % threshold_prob}.csv'

    wsi_tissue_patches = {}
    with open(csv_file_path, newline='', mode='w') as medidas_file:
        medidas_writer = csv.writer(medidas_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
        medidas_writer.writerow(['wsi_image', 'patch_image', 'auc', 'accuracy', 'precision', 'f1/dice', 'jaccard', 'sensitivity/recall', 'specificity', 'pixels', 'tp', 'tn', 'fp', 'fn'])

        for batch_idx, (data, target, fname, original_size) in enumerate(dataloaders['test']):

            sum_auc = 0.0 
            sum_accuracy = 0.0 
            sum_precision = 0.0 
            sum_f1 = 0.0 
            sum_jaccard = 0.0
            sum_recall = 0.0
            sum_specificity = 0.0
            sum_tp = 0.0
            sum_tn = 0.0
            sum_fp = 0.0
            sum_fn = 0.0

            # wsi image number
            wsi_image_number = fname[0].split("_")[0]
            if wsi_image_number not in wsi_tissue_patches:

                # extract the tissue region from original image and draw the heat grid
                wsi_image_path = "{}/{}.png".format(wsi_images_dir_tumor, wsi_image_number)
                #if not os.path.exists(wsi_image_path):
                #    wsi_image_path = "{}/{}.tif".format(wsi_images_dir_normal, wsi_image_number)

                 # scale down image
                print(wsi_image_path)
                wsi_image = open_wsi(wsi_image_path)
                pil_scaled_down_image = scale_down_wsi(wsi_image, magnification, False)
                np_scaled_down_image = pil_to_np(pil_scaled_down_image)

                # extract tissue region 
                np_tissue_mask, np_masked_image = extract_normal_region_from_wsi(wsi_image_path, np_scaled_down_image, None)
                pil_masked_image = np_to_pil(np_masked_image)

                # draw the heat grid
                pil_img_result, heat_grid, number_of_tiles = draw_heat_grid(np_masked_image, tile_size)

                tissue_patches = []
                for idx, (position, row, column, location, size, color) in enumerate(heat_grid):
                    if color != GREEN_COLOR: 
                        tissue_patches.append("{}_r{}c{}.png".format(wsi_image_number, row, column))

                wsi_tissue_patches[wsi_image_number] = tissue_patches
                #print(wsi_tissue_patches)

            # check if the patch was excluded in preprocessing step
            patch_excludde_in_preprocessing = fname[0] not in wsi_tissue_patches[wsi_image_number]

            # load the mask image
            mask_np_img = target[0].numpy()

            # roi x non_roi classes
            wsi_class = class_name if wsi_image_path.find(class_name) > 0 else "normal"
            patch_class = "roi" if np.max(np.unique(mask_np_img)) > 0 else 'non_roi'


            # load the predicted image result
            patch_results_dir = "{}/{}/patch/{}x{}/{}".format(results_dir, wsi_class, patch_size, patch_size, fname[0].split('_')[0])
            print("Patch results dir: " + patch_results_dir)
            unet_result_img = "{}/01-unet_result/{}".format(patch_results_dir, fname[0])
            print(unet_result_img)
            predicted_pil_img = Image.fromarray(np.zeros(mask_np_img.shape)) if patch_excludde_in_preprocessing else load_pil_image(unet_result_img, gray=True) if os.path.isfile(unet_result_img) else Image.fromarray(np.zeros(mask_np_img.shape))
            predicted_np_img = np.copy(pil_to_np(predicted_pil_img)) 
            predicted_np_img = predicted_np_img * (1.0/255)
            print(predicted_np_img.max())
            print(threshold_prob)
            predicted_np_img = basic_threshold(predicted_np_img, threshold=threshold_prob, output_type="float")

            predicted_labels = measure.label(predicted_np_img, connectivity=2)
            #predicted_np_img = np.zeros((predicted_np_img.shape[0], predicted_np_img.shape[1]))
            #labels = np.unique(predicted_labels)
            #properties = measure.regionprops(predicted_labels)
            #for lbl in range(1, np.max(labels)):
            #    major_axis_length = properties[lbl-1].major_axis_length
            #    if major_axis_length > threshold_itc:
            #        predicted_np_img[predicted_labels == lbl] = 1

            # SAVE BINARY IMAGES
            bin_images_path = f'../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/binary_images/prob_{"%.3f" % threshold_prob}/'
            if not os.path.isdir(bin_images_path):
                os.mkdir(bin_images_path)

            predicted_np_img_255 = predicted_np_img * 255
            mean = get_mean_props_area(predicted_np_img_255)
            predicted_np_img_255 = remove_noise(predicted_np_img_255, mean)
            predicted_np_img_255 = fill_components_contours(predicted_np_img_255)
    
            new_p = Image.fromarray(predicted_np_img_255)
            if new_p.mode != 'RGB':
                new_p = new_p.convert('RGB')
            new_p.save(bin_images_path + fname[0])

            # metrics
            auc = roc_auc_score(mask_np_img, predicted_np_img)
            precision = precision_score(mask_np_img, predicted_np_img)
            recall = recall_score(mask_np_img, predicted_np_img)
            accuracy = accuracy_score(mask_np_img, predicted_np_img)
            f1 = f1_score(mask_np_img, predicted_np_img)
            specificity = specificity_score(mask_np_img, predicted_np_img)
            jaccard = jaccard_score(mask_np_img, predicted_np_img)

            total_pixels, tn, fp, fn, tp = tn_fp_fn_tp(mask_np_img, predicted_np_img)

            print("Results for {:26} ({:7} - {:8} - {:04.2f} accuracy)".format(fname[0].split("_")[1], patch_class, "excluded" if patch_excludde_in_preprocessing else "unet", accuracy))
            print("   Precision: \t{}".format(precision))
            print("   Recall/Sen: \t{}".format(recall))
            print("   F1/Dice: \t{}".format(f1))
            print("   Accuracy: \t{}".format(accuracy))
            print("   Specificity: {}".format(specificity))
            print("   Jaccard: \t{}".format(jaccard))
            print("   TP = {} TN = {} FP = {} FN = {}".format(tp, tn, fp, fn))
            print("-")

            medidas_writer.writerow([wsi_image_number, patch_class, auc, accuracy, precision, f1, jaccard, recall, specificity, total_pixels, tp, tn, fp, fn])

            sum_auc = sum_auc + auc 
            sum_accuracy = sum_accuracy + accuracy
            sum_precision = sum_precision + precision 
            sum_f1 = sum_f1 + f1
            sum_jaccard = sum_jaccard + jaccard
            sum_recall = sum_recall + recall
            sum_specificity = sum_specificity + specificity
            sum_tp = sum_tp + tp
            sum_tn = sum_tn + tn
            sum_fp = sum_fp + fp
            sum_fn = sum_fn + fn
            
    mean_writer.writerow([wsi_image_number, 
                          patch_class, 
                          sum_auc/dataset_test_size, 
                          sum_accuracy/dataset_test_size, 
                          sum_precision/dataset_test_size, 
                          sum_f1/dataset_test_size, 
                          sum_jaccard/dataset_test_size,
                          sum_recall/dataset_test_size,
                          sum_specificity/dataset_test_size,
                          sum_tp/dataset_test_size,
                          sum_tn/dataset_test_size,
                          sum_fp/dataset_test_size,
                          sum_fn/dataset_test_size])
# Out:
# 2024-06-03 11:46:03,404 :: INFO transform :: Epoch: '29' augmentation no_augmentation None
# ../../datasets/BONE_CHANNELS/testing/bones/202.png
# 2024-06-03 11:46:05,004 :: INFO extract_normal_region_from_wsi :: 	 Extracting normal regions from wsi image: '202.png'
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202/01-unet_result/202_r2c2.png
# 1.0
# 0.0
# Results for r2c2.png                   (roi     - unet     - 0.91 accuracy)
#    Precision: 	0.16433654440198614
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.2822835806229734
#    Accuracy: 	0.91083740234375
#    Specificity: 0.9092461072814835
#    Jaccard: 	0.16433654440198614
#    TP = 7182 TN = 365897 FP = 36521 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202/01-unet_result/202_r2c3.png
# 0.996078431372549
# 0.0
# Results for r2c3.png                   (roi     - unet     - 0.88 accuracy)
#    Precision: 	0.21521613832853026
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.35420223866439005
#    Accuracy: 	0.88365234375
#    Specificity: 0.8798177191694975
#    Jaccard: 	0.21521613832853026
#    TP = 13069 TN = 348875 FP = 47656 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202/01-unet_result/202_r2c4.png
# 1.0
# 0.0
# Results for r2c4.png                   (roi     - unet     - 0.89 accuracy)
#    Precision: 	0.18967305278096175
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.31886584694439346
#    Accuracy: 	0.8912646484375
#    Specificity: 0.888424876307384
#    Jaccard: 	0.18967305278096175
#    TP = 10425 TN = 354637 FP = 44538 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202/01-unet_result/202_r2c5.png
# 0.996078431372549
# 0.0
# Results for r2c5.png                   (roi     - unet     - 0.85 accuracy)
#    Precision: 	0.17777288104836098
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.30187973234724425
#    Accuracy: 	0.8451318359375
#    Specificity: 0.8397665988860401
#    Jaccard: 	0.17777288104836098
#    TP = 13715 TN = 332451 FP = 63434 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202/01-unet_result/202_r2c6.png
# 0.996078431372549
# 0.0
# Results for r2c6.png                   (roi     - unet     - 0.89 accuracy)
#    Precision: 	0.3175247992442135
#    Recall/Sen: 	0.9998016856717898
#    F1/Dice: 	0.4819789674952199
#    Accuracy: 	0.894169921875
#    Specificity: 0.8886988675756875
#    Jaccard: 	0.3175048020908776
#    TP = 20166 TN = 346086 FP = 43344 FN = 4
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202/01-unet_result/202_r2c7.png
# 0.996078431372549
# 0.0
# Results for r2c7.png                   (roi     - unet     - 0.92 accuracy)
#    Precision: 	0.3973374698109132
#    Recall/Sen: 	0.9897774516996821
#    F1/Dice: 	0.5670412194916916
#    Accuracy: 	0.9245556640625
#    Specificity: 0.9211291130783364
#    Jaccard: 	0.3957135593883218
#    TP = 20236 TN = 358462 FP = 30693 FN = 209
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202/01-unet_result/202_r3c1.png
# 1.0
# 0.0
# Results for r3c1.png                   (roi     - unet     - 0.89 accuracy)
#    Precision: 	0.15056411742335066
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.2617222545763619
#    Accuracy: 	0.88548583984375
#    Specificity: 0.8831132907701739
#    Jaccard: 	0.15056411742335066
#    TP = 8314 TN = 354381 FP = 46905 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202/01-unet_result/202_r3c2.png
# 0.996078431372549
# 0.0
# Results for r3c2.png                   (roi     - unet     - 0.86 accuracy)
#    Precision: 	0.17713310580204777
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.3009567990721948
#    Accuracy: 	0.86461669921875
#    Specificity: 0.8605527796149001
#    Jaccard: 	0.17713310580204777
#    TP = 11937 TN = 342210 FP = 55453 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202/01-unet_result/202_r3c8.png
# 0.996078431372549
# 0.0
# Results for r3c8.png                   (roi     - unet     - 0.89 accuracy)
#    Precision: 	0.1511945775913721
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.26267423515443294
#    Accuracy: 	0.88932373046875
#    Specificity: 0.887097939107154
#    Jaccard: 	0.1511945775913721
#    TP = 8075 TN = 356192 FP = 45333 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202/01-unet_result/202_r3c9.png
# 0.996078431372549
# 0.0
# Results for r3c9.png                   (roi     - unet     - 0.94 accuracy)
#    Precision: 	0.2759085169075347
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.43248949787758145
#    Accuracy: 	0.93700439453125
#    Specificity: 0.9354550639370836
#    Jaccard: 	0.2759085169075347
#    TP = 9832 TN = 373965 FP = 25803 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202/01-unet_result/202_r4c1.png
# 1.0
# 0.0
# Results for r4c1.png                   (roi     - unet     - 0.91 accuracy)
#    Precision: 	0.17250934398762727
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.29425666391865896
#    Accuracy: 	0.90594970703125
#    Specificity: 0.904068790170556
#    Jaccard: 	0.17250934398762727
#    TP = 8031 TN = 363046 FP = 38523 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202/01-unet_result/202_r4c2.png
# 1.0
# 0.0
# Results for r4c2.png                   (roi     - unet     - 0.94 accuracy)
#    Precision: 	0.2708339470350841
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.42623026819035253
#    Accuracy: 	0.93956787109375
#    Specificity: 0.938180247049245
#    Jaccard: 	0.2708339470350841
#    TP = 9194 TN = 375653 FP = 24753 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202/01-unet_result/202_r5c1.png
# 1.0
# 0.0
# Results for r5c1.png                   (roi     - unet     - 0.92 accuracy)
#    Precision: 	0.13173880030372057
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.23280778262328078
#    Accuracy: 	0.91624755859375
#    Specificity: 0.9151695743023529
#    Jaccard: 	0.13173880030372057
#    TP = 5205 TN = 370090 FP = 34305 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202/01-unet_result/202_r5c10.png
# 0.996078431372549
# 0.0
# Results for r5c10.png                  (roi     - unet     - 0.87 accuracy)
#    Precision: 	0.1532258064516129
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.26573426573426573
#    Accuracy: 	0.87003173828125
#    Specificity: 0.8669015193753484
#    Jaccard: 	0.1532258064516129
#    TP = 9633 TN = 346732 FP = 53235 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202/01-unet_result/202_r5c2.png
# 1.0
# 0.0
# Results for r5c2.png                   (roi     - unet     - 0.88 accuracy)
#    Precision: 	0.1726605126797296
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.2944765527836711
#    Accuracy: 	0.88227783203125
#    Specificity: 0.8793128045712912
#    Jaccard: 	0.1726605126797296
#    TP = 10063 TN = 351318 FP = 48219 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202/01-unet_result/202_r6c10.png
# 0.996078431372549
# 0.0
# Results for r6c10.png                  (roi     - unet     - 0.88 accuracy)
#    Precision: 	0.19815954938433325
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.33077322546259597
#    Accuracy: 	0.8804443359375
#    Specificity: 0.8768044115945237
#    Jaccard: 	0.19815954938433325
#    TP = 12102 TN = 348528 FP = 48970 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202/01-unet_result/202_r6c2.png
# 0.996078431372549
# 0.0
# Results for r6c2.png                   (roi     - unet     - 0.85 accuracy)
#    Precision: 	0.2027991855040338
#    Recall/Sen: 	0.9998093906855582
#    F1/Dice: 	0.3372012042900153
#    Accuracy: 	0.84897216796875
#    Specificity: 0.8429445921276796
#    Jaccard: 	0.20279134502622523
#    TP = 15736 TN = 332003 FP = 61858 FN = 3
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202/01-unet_result/202_r7c10.png
# 0.996078431372549
# 0.0
# Results for r7c10.png                  (roi     - unet     - 0.89 accuracy)
#    Precision: 	0.1480260093529335
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.2578791911454445
#    Accuracy: 	0.888359375
#    Specificity: 0.8861510500304988
#    Jaccard: 	0.1480260093529335
#    TP = 7945 TN = 355927 FP = 45728 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202/01-unet_result/202_r7c2.png
# 1.0
# 0.0
# Results for r7c2.png                   (roi     - unet     - 0.94 accuracy)
#    Precision: 	0.1816805971176005
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.30749526997525833
#    Accuracy: 	0.94191650390625
#    Specificity: 0.9411577026004284
#    Jaccard: 	0.1816805971176005
#    TP = 5282 TN = 380527 FP = 23791 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202/01-unet_result/202_r7c3.png
# 1.0
# 0.0
# Results for r7c3.png                   (roi     - unet     - 0.89 accuracy)
#    Precision: 	0.23613353928245454
#    Recall/Sen: 	0.9981451253895237
#    F1/Dice: 	0.381916252661462
#    Accuracy: 	0.89369140625
#    Specificity: 0.890137381917692
#    Jaccard: 	0.23602996648946437
#    TP = 13453 TN = 352603 FP = 43519 FN = 25
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202/01-unet_result/202_r8c4.png
# 0.996078431372549
# 0.0
# Results for r8c4.png                   (roi     - unet     - 0.88 accuracy)
#    Precision: 	0.14856672656131925
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.25869933914263993
#    Accuracy: 	0.8762158203125
#    Specificity: 0.8734831679363598
#    Jaccard: 	0.14856672656131925
#    TP = 8847 TN = 350051 FP = 50702 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202/01-unet_result/202_r8c7.png
# 0.996078431372549
# 0.0
# Results for r8c7.png                   (roi     - unet     - 0.90 accuracy)
#    Precision: 	0.2014347782156209
#    Recall/Sen: 	0.9989977951493285
#    F1/Dice: 	0.3352673090829591
#    Accuracy: 	0.90349853515625
#    Specificity: 0.901114052779877
#    Jaccard: 	0.20139408021012223
#    TP = 9968 TN = 360105 FP = 39517 FN = 10
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202/01-unet_result/202_r8c8.png
# 0.9882352941176471
# 0.0
# Results for r8c8.png                   (roi     - unet     - 0.84 accuracy)
#    Precision: 	0.30040510387556596
#    Recall/Sen: 	0.9969086987778577
#    F1/Dice: 	0.4616870037122738
#    Accuracy: 	0.8421044921875
#    Specificity: 0.8308240347844308
#    Jaccard: 	0.3001255302571206
#    TP = 27734 TN = 317192 FP = 64588 FN = 86
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202/01-unet_result/202_r8c9.png
# 0.996078431372549
# 0.0
# Results for r8c9.png                   (roi     - unet     - 0.85 accuracy)
#    Precision: 	0.15173051446235372
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.2634826681364502
#    Accuracy: 	0.84992919921875
#    Specificity: 0.8457896915492781
#    Jaccard: 	0.15173051446235372
#    TP = 10995 TN = 337136 FP = 61469 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202/01-unet_result/202_r9c6.png
# 0.996078431372549
# 0.0
# Results for r9c6.png                   (roi     - unet     - 0.90 accuracy)
#    Precision: 	0.34392054136651384
#    Recall/Sen: 	0.996701310438319
#    F1/Dice: 	0.511383659463971
#    Accuracy: 	0.8970947265625
#    Specificity: 0.8914057862544197
#    Jaccard: 	0.3435295217032411
#    TP = 22057 TN = 345393 FP = 42077 FN = 73
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202/01-unet_result/202_r9c7.png
# 1.0
# 0.0
# Results for r9c7.png                   (roi     - unet     - 0.92 accuracy)
#    Precision: 	0.3519724863443253
#    Recall/Sen: 	0.9980495640201927
#    F1/Dice: 	0.520415183512309
#    Accuracy: 	0.9217138671875
#    Specificity: 0.9183207196915607
#    Jaccard: 	0.3517305515122109
#    TP = 17398 TN = 360136 FP = 32032 FN = 34
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/202/01-unet_result/202_r9c8.png
# 1.0
# 0.0
# Results for r9c8.png                   (roi     - unet     - 0.93 accuracy)
#    Precision: 	0.21067125645438897
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.34802388399203865
#    Accuracy: 	0.92722412109375
#    Specificity: 0.925782533786139
#    Jaccard: 	0.21067125645438897
#    TP = 7956 TN = 371835 FP = 29809 FN = 0
# -
# ../../datasets/BONE_CHANNELS/testing/bones/203.png
# 2024-06-03 11:46:19,646 :: INFO extract_normal_region_from_wsi :: 	 Extracting normal regions from wsi image: '203.png'
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203/01-unet_result/203_r10c6.png
# 0.996078431372549
# 0.0
# Results for r10c6.png                  (roi     - unet     - 0.95 accuracy)
#    Precision: 	0.37583937460328065
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.5463419372071
#    Accuracy: 	0.95438720703125
#    Specificity: 0.9530990335132421
#    Jaccard: 	0.37583937460328065
#    TP = 11250 TN = 379667 FP = 18683 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203/01-unet_result/203_r2c2.png
# 0.996078431372549
# 0.0
# Results for r2c2.png                   (roi     - unet     - 0.90 accuracy)
#    Precision: 	0.17057383511057633
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.2914362682546434
#    Accuracy: 	0.902392578125
#    Specificity: 0.9003931456133619
#    Jaccard: 	0.17057383511057633
#    TP = 8222 TN = 361398 FP = 39980 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203/01-unet_result/203_r2c3.png
# 1.0
# 0.0
# Results for r2c3.png                   (roi     - unet     - 0.92 accuracy)
#    Precision: 	0.2891135690212843
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.4485463127050691
#    Accuracy: 	0.92326904296875
#    Specificity: 0.9207974436643499
#    Jaccard: 	0.2891135690212843
#    TP = 12782 TN = 365389 FP = 31429 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203/01-unet_result/203_r2c4.png
# 0.9921568627450981
# 0.0
# Results for r2c4.png                   (roi     - unet     - 0.86 accuracy)
#    Precision: 	0.2573196979152074
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.409314668881551
#    Accuracy: 	0.857626953125
#    Specificity: 0.8502394740559073
#    Jaccard: 	0.2573196979152074
#    TP = 20205 TN = 331079 FP = 58316 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203/01-unet_result/203_r2c5.png
# 0.996078431372549
# 0.0
# Results for r2c5.png                   (roi     - unet     - 0.87 accuracy)
#    Precision: 	0.16926219437277307
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.2895196563907898
#    Accuracy: 	0.86794189453125
#    Specificity: 0.8642903916162166
#    Jaccard: 	0.16926219437277307
#    TP = 11021 TN = 344488 FP = 54091 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203/01-unet_result/203_r2c6.png
# 0.996078431372549
# 0.0
# Results for r2c6.png                   (roi     - unet     - 0.87 accuracy)
#    Precision: 	0.2500756320679968
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.40009680318989554
#    Accuracy: 	0.87291015625
#    Specificity: 0.8672856738586736
#    Jaccard: 	0.2500756320679968
#    TP = 17359 TN = 340185 FP = 52056 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203/01-unet_result/203_r2c7.png
# 1.0
# 0.0
# Results for r2c7.png                   (roi     - unet     - 0.93 accuracy)
#    Precision: 	0.24543802828027492
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.39413928707344925
#    Accuracy: 	0.9300390625
#    Specificity: 0.9284099340709855
#    Jaccard: 	0.24543802828027492
#    TP = 9321 TN = 371623 FP = 28656 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203/01-unet_result/203_r3c1.png
# 1.0
# 0.0
# Results for r3c1.png                   (roi     - unet     - 0.92 accuracy)
#    Precision: 	0.19364668058254755
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.32446231155778893
#    Accuracy: 	0.91794921875
#    Specificity: 0.9162999434661008
#    Jaccard: 	0.19364668058254755
#    TP = 8071 TN = 367921 FP = 33608 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203/01-unet_result/203_r3c2.png
# 0.996078431372549
# 0.0
# Results for r3c2.png                   (roi     - unet     - 0.87 accuracy)
#    Precision: 	0.20339008725157537
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.33802852359553387
#    Accuracy: 	0.87160888671875
#    Specificity: 0.8672574859972789
#    Jaccard: 	0.20339008725157537
#    TP = 13427 TN = 343584 FP = 52589 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203/01-unet_result/203_r3c6.png
# 0.996078431372549
# 0.0
# Results for r3c6.png                   (roi     - unet     - 0.94 accuracy)
#    Precision: 	0.21722880308647557
#    Recall/Sen: 	0.9998612652608213
#    F1/Dice: 	0.3569146960505138
#    Accuracy: 	0.93659423828125
#    Specificity: 0.935460943557526
#    Jaccard: 	0.21722225571161613
#    TP = 7207 TN = 376422 FP = 25970 FN = 1
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203/01-unet_result/203_r3c7.png
# 0.996078431372549
# 0.0
# Results for r3c7.png                   (roi     - unet     - 0.90 accuracy)
#    Precision: 	0.1596364735342371
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.2753215808187047
#    Accuracy: 	0.90495849609375
#    Specificity: 0.903211049091881
#    Jaccard: 	0.1596364735342371
#    TP = 7395 TN = 363276 FP = 38929 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203/01-unet_result/203_r3c8.png
# 1.0
# 0.0
# Results for r3c8.png                   (roi     - unet     - 0.91 accuracy)
#    Precision: 	0.247246382915991
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.3964675886057782
#    Accuracy: 	0.91273681640625
#    Specificity: 0.9101618659830091
#    Jaccard: 	0.247246382915991
#    TP = 11740 TN = 362117 FP = 35743 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203/01-unet_result/203_r3c9.png
# 1.0
# 0.0
# Results for r3c9.png                   (roi     - unet     - 0.93 accuracy)
#    Precision: 	0.23728556247153484
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.38355828220858895
#    Accuracy: 	0.92640625
#    Specificity: 0.9246818016001119
#    Jaccard: 	0.23728556247153484
#    TP = 9378 TN = 370078 FP = 30144 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203/01-unet_result/203_r4c1.png
# 1.0
# 0.0
# Results for r4c1.png                   (roi     - unet     - 0.91 accuracy)
#    Precision: 	0.16832270151058834
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.2881441938823147
#    Accuracy: 	0.91437744140625
#    Specificity: 0.9128675137017953
#    Jaccard: 	0.16832270151058834
#    TP = 7098 TN = 367431 FP = 35071 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203/01-unet_result/203_r4c2.png
# 1.0
# 0.0
# Results for r4c2.png                   (roi     - unet     - 0.91 accuracy)
#    Precision: 	0.2046270087146455
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.33973505032563645
#    Accuracy: 	0.9128759765625
#    Specificity: 0.9108783549232179
#    Jaccard: 	0.2046270087146455
#    TP = 9181 TN = 364733 FP = 35686 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203/01-unet_result/203_r4c9.png
# 0.996078431372549
# 0.0
# Results for r4c9.png                   (roi     - unet     - 0.92 accuracy)
#    Precision: 	0.22949319568277804
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.3733134863838476
#    Accuracy: 	0.91982666015625
#    Specificity: 0.9178653340636638
#    Jaccard: 	0.22949319568277804
#    TP = 9781 TN = 366980 FP = 32839 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203/01-unet_result/203_r5c2.png
# 0.996078431372549
# 0.0
# Results for r5c2.png                   (roi     - unet     - 0.87 accuracy)
#    Precision: 	0.16866278606171756
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.28864234931291877
#    Accuracy: 	0.87273193359375
#    Specificity: 0.8693587353141665
#    Jaccard: 	0.16866278606171756
#    TP = 10576 TN = 346895 FP = 52129 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203/01-unet_result/203_r5c9.png
# 1.0
# 0.0
# Results for r5c9.png                   (roi     - unet     - 0.91 accuracy)
#    Precision: 	0.15318366556996324
#    Recall/Sen: 	0.9966944750511569
#    F1/Dice: 	0.26555390131896245
#    Accuracy: 	0.91448974609375
#    Specificity: 0.9131946424895907
#    Jaccard: 	0.15310588292187538
#    TP = 6332 TN = 368243 FP = 35004 FN = 21
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203/01-unet_result/203_r6c10.png
# 0.996078431372549
# 0.0
# Results for r6c10.png                  (roi     - unet     - 0.89 accuracy)
#    Precision: 	0.23318341160129638
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.3781812330714152
#    Accuracy: 	0.8867822265625
#    Specificity: 0.882745298332735
#    Jaccard: 	0.23318341160129638
#    TP = 14102 TN = 349124 FP = 46374 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203/01-unet_result/203_r6c2.png
# 0.996078431372549
# 0.0
# Results for r6c2.png                   (roi     - unet     - 0.89 accuracy)
#    Precision: 	0.2724872834975211
#    Recall/Sen: 	0.9996456832408173
#    F1/Dice: 	0.4282425560980546
#    Accuracy: 	0.8896435546875
#    Specificity: 0.8848996348041338
#    Jaccard: 	0.2724609689361017
#    TP = 16928 TN = 347470 FP = 45196 FN = 6
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203/01-unet_result/203_r7c10.png
# 0.996078431372549
# 0.0
# Results for r7c10.png                  (roi     - unet     - 0.87 accuracy)
#    Precision: 	0.2407833761327076
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.38811509045710274
#    Accuracy: 	0.87440673828125
#    Specificity: 0.8691966385699937
#    Jaccard: 	0.2407833761327076
#    TP = 16315 TN = 341842 FP = 51443 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203/01-unet_result/203_r7c3.png
# 0.996078431372549
# 0.0
# Results for r7c3.png                   (roi     - unet     - 0.90 accuracy)
#    Precision: 	0.23882036924939468
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.38556093389729573
#    Accuracy: 	0.90176025390625
#    Specificity: 0.8986359342527867
#    Jaccard: 	0.23882036924939468
#    TP = 12625 TN = 356736 FP = 40239 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203/01-unet_result/203_r8c3.png
# 0.996078431372549
# 0.0
# Results for r8c3.png                   (roi     - unet     - 0.88 accuracy)
#    Precision: 	0.2639163224995511
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.4176167643402593
#    Accuracy: 	0.87990478515625
#    Specificity: 0.8745009095246234
#    Jaccard: 	0.2639163224995511
#    TP = 17637 TN = 342772 FP = 49191 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203/01-unet_result/203_r8c4.png
# 0.996078431372549
# 0.0
# Results for r8c4.png                   (roi     - unet     - 0.87 accuracy)
#    Precision: 	0.1318304626815265
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.23295090038342756
#    Accuracy: 	0.87447998046875
#    Specificity: 0.8720410758773797
#    Jaccard: 	0.1318304626815265
#    TP = 7807 TN = 350380 FP = 51413 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203/01-unet_result/203_r8c8.png
# 0.996078431372549
# 0.0
# Results for r8c8.png                   (roi     - unet     - 0.81 accuracy)
#    Precision: 	0.10031204636117366
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.1823338146536052
#    Accuracy: 	0.80783447265625
#    Specificity: 0.8036270283216573
#    Jaccard: 	0.10031204636117366
#    TP = 8776 TN = 322113 FP = 78711 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203/01-unet_result/203_r8c9.png
# 0.9921568627450981
# 0.0
# Results for r8c9.png                   (roi     - unet     - 0.79 accuracy)
#    Precision: 	0.11325541822479901
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.20346708647579997
#    Accuracy: 	0.7875341796875
#    Specificity: 0.7816078396928366
#    Jaccard: 	0.11325541822479901
#    TP = 11115 TN = 311459 FP = 87026 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203/01-unet_result/203_r9c5.png
# 0.996078431372549
# 0.0
# Results for r9c5.png                   (roi     - unet     - 0.92 accuracy)
#    Precision: 	0.23847303415234494
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.3851081575071425
#    Accuracy: 	0.91540283203125
#    Specificity: 0.9131007225096489
#    Jaccard: 	0.23847303415234494
#    TP = 10851 TN = 364098 FP = 34651 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203/01-unet_result/203_r9c6.png
# 0.996078431372549
# 0.0
# Results for r9c6.png                   (roi     - unet     - 0.89 accuracy)
#    Precision: 	0.20550009751945955
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.3409375045963317
#    Accuracy: 	0.89060302734375
#    Specificity: 0.8874174015728248
#    Jaccard: 	0.20550009751945955
#    TP = 11590 TN = 353201 FP = 44809 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203/01-unet_result/203_r9c7.png
# 0.996078431372549
# 0.0
# Results for r9c7.png                   (roi     - unet     - 0.83 accuracy)
#    Precision: 	0.2191866087207816
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.3595620344793006
#    Accuracy: 	0.82849365234375
#    Specificity: 0.8198189186416334
#    Jaccard: 	0.2191866087207816
#    TP = 19720 TN = 319631 FP = 70249 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203/01-unet_result/203_r9c8.png
# 0.996078431372549
# 0.0
# Results for r9c8.png                   (roi     - unet     - 0.88 accuracy)
#    Precision: 	0.25417132773479967
#    Recall/Sen: 	0.9984526830475955
#    F1/Dice: 	0.4051942832743074
#    Accuracy: 	0.8843701171875
#    Specificity: 0.8796852403016447
#    Jaccard: 	0.2540712508268498
#    TP = 16132 TN = 346106 FP = 47337 FN = 25
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/203/01-unet_result/203_r9c9.png
# 1.0
# 0.0
# Results for r9c9.png                   (roi     - unet     - 0.93 accuracy)
#    Precision: 	0.22196632376273095
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.3632936840341766
#    Accuracy: 	0.925771484375
#    Specificity: 0.9241655567361557
#    Jaccard: 	0.22196632376273095
#    TP = 8674 TN = 370522 FP = 30404 FN = 0
# -
# ../../datasets/BONE_CHANNELS/testing/bones/204.png
# 2024-06-03 11:46:36,701 :: INFO extract_normal_region_from_wsi :: 	 Extracting normal regions from wsi image: '204.png'
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/204
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/204/01-unet_result/204_r2c2.png
# 1.0
# 0.0
# Results for r2c2.png                   (roi     - unet     - 0.90 accuracy)
#    Precision: 	0.15353710732455786
#    Recall/Sen: 	0.9687898089171975
#    F1/Dice: 	0.2650657000453104
#    Accuracy: 	0.897041015625
#    Specificity: 0.895639079029247
#    Jaccard: 	0.15278140506659701
#    TP = 7605 TN = 359823 FP = 41927 FN = 245
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/204
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/204/01-unet_result/204_r2c3.png
# 1.0
# 0.0
# Results for r2c3.png                   (roi     - unet     - 0.90 accuracy)
#    Precision: 	0.24183952403923462
#    Recall/Sen: 	0.993103448275862
#    F1/Dice: 	0.3889599287366561
#    Accuracy: 	0.89616943359375
#    Specificity: 0.8928327903629063
#    Jaccard: 	0.24143404976366717
#    TP = 13536 TN = 353535 FP = 42435 FN = 94
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/204
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/204/01-unet_result/204_r2c4.png
# 0.996078431372549
# 0.0
# Results for r2c4.png                   (roi     - unet     - 0.88 accuracy)
#    Precision: 	0.27964421114027416
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.4370655666719844
#    Accuracy: 	0.8793896484375
#    Specificity: 0.8734651223547854
#    Jaccard: 	0.27964421114027416
#    TP = 19178 TN = 341020 FP = 49402 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/204
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/204/01-unet_result/204_r2c5.png
# 1.0
# 0.0
# Results for r2c5.png                   (roi     - unet     - 0.88 accuracy)
#    Precision: 	0.22110862693701333
#    Recall/Sen: 	0.9981901712376444
#    F1/Dice: 	0.36202522058545084
#    Accuracy: 	0.87660888671875
#    Specificity: 0.8721896395553014
#    Jaccard: 	0.22102002126970915
#    TP = 14340 TN = 344719 FP = 50515 FN = 26
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/204
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/204/01-unet_result/204_r2c6.png
# 0.996078431372549
# 0.0
# Results for r2c6.png                   (roi     - unet     - 0.87 accuracy)
#    Precision: 	0.26197307437651735
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.41518013291360617
#    Accuracy: 	0.869375
#    Specificity: 0.8630237987957236
#    Jaccard: 	0.26197307437651735
#    TP = 18992 TN = 337104 FP = 53504 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/204
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/204/01-unet_result/204_r2c7.png
# 1.0
# 0.0
# Results for r2c7.png                   (roi     - unet     - 0.92 accuracy)
#    Precision: 	0.3513372093023256
#    Recall/Sen: 	0.9998345466578424
#    F1/Dice: 	0.5199621407675099
#    Accuracy: 	0.9182763671875
#    Specificity: 0.9144987585192148
#    Jaccard: 	0.3513167839079123
#    TP = 18129 TN = 357997 FP = 33471 FN = 3
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/204
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/204/01-unet_result/204_r2c8.png
# 1.0
# 0.0
# Results for r2c8.png                   (roi     - unet     - 0.95 accuracy)
#    Precision: 	0.28683181225554105
#    Recall/Sen: 	1.0
#    F1/Dice: 	0.44579533941236066
#    Accuracy: 	0.95325927734375
#    Specificity: 0.9523637720826076
#    Jaccard: 	0.28683181225554105
#    TP = 7700 TN = 382755 FP = 19145 FN = 0
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/204
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/204/01-unet_result/204_r3c2.png
# 0.996078431372549
# 0.0
# Results for r3c2.png                   (roi     - unet     - 0.90 accuracy)
#    Precision: 	0.27543486872906686
#    Recall/Sen: 	0.9866477455976262
#    F1/Dice: 	0.4306488168137731
#    Accuracy: 	0.90125732421875
#    Specificity: 0.8978982331760963
#    Jaccard: 	0.27441201270160204
#    TP = 15296 TN = 353859 FP = 40238 FN = 207
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/204
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/204/01-unet_result/204_r3c3.png
# 0.996078431372549
# 0.0
# Results for r3c3.png                   (roi     - unet     - 0.92 accuracy)
#    Precision: 	0.32969926995991555
#    Recall/Sen: 	0.9981825643430849
#    F1/Dice: 	0.49567673003580887
#    Accuracy: 	0.9154150390625
#    Specificity: 0.9118185778373324
#    Jaccard: 	0.3295014708159158
#    TP = 17026 TN = 357928 FP = 34615 FN = 31
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/204
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/204/01-unet_result/204_r3c9.png
# 0.996078431372549
# 0.0
# Results for r3c9.png                   (roi     - unet     - 0.92 accuracy)
#    Precision: 	0.2369486571312202
#    Recall/Sen: 	0.9939698492462311
#    F1/Dice: 	0.38267329605912287
#    Accuracy: 	0.92209716796875
#    Specificity: 0.9203077692981358
#    Jaccard: 	0.23660853130457665
#    TP = 9890 TN = 367801 FP = 31849 FN = 60
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/204
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/204/01-unet_result/204_r4c10.png
# 0.996078431372549
# 0.0
# Results for r4c10.png                  (roi     - unet     - 0.95 accuracy)
#    Precision: 	0.3007168723671569
#    Recall/Sen: 	0.9854686364737224
#    F1/Dice: 	0.4608154020385051
#    Accuracy: 	0.953505859375
#    Specificity: 0.9528481943080963
#    Jaccard: 	0.299389301743801
#    TP = 8138 TN = 382418 FP = 18924 FN = 120
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/204
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/204/01-unet_result/204_r4c2.png
# 0.996078431372549
# 0.0
# Results for r4c2.png                   (roi     - unet     - 0.90 accuracy)
#    Precision: 	0.2725150100066711
#    Recall/Sen: 	0.9888520830679067
#    F1/Dice: 	0.42727773190200935
#    Accuracy: 	0.8984033203125
#    Specificity: 0.8947987062771958
#    Jaccard: 	0.27168034723559165
#    TP = 15523 TN = 352463 FP = 41439 FN = 175
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/204
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/204/01-unet_result/204_r4c9.png
# 0.996078431372549
# 0.0
# ...
#    Accuracy: 	0.9718359375
#    Specificity: 0.999979694400731
#    Jaccard: 	0.261837727156386
#    TP = 4092 TN = 393972 FP = 8 FN = 11528
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314/01-unet_result/314_r2c10.png
# 0.996078431372549
# 0.9500000000000001
# Results for r2c10.png                  (roi     - unet     - 0.98 accuracy)
#    Precision: 	0.8445914029286726
#    Recall/Sen: 	0.2241163198796691
#    F1/Dice: 	0.35423476968796436
#    Accuracy: 	0.98408447265625
#    Specificity: 0.9991808217677318
#    Jaccard: 	0.21524015890213075
#    TP = 1788 TN = 401293 FP = 329 FN = 6190
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314/01-unet_result/314_r3c10.png
# 0.996078431372549
# 0.9500000000000001
# Results for r3c10.png                  (roi     - unet     - 0.98 accuracy)
#    Precision: 	0.998347410943812
#    Recall/Sen: 	0.3941283073577383
#    F1/Dice: 	0.5651473416142612
#    Accuracy: 	0.97957275390625
#    Specificity: 0.999977261530299
#    Jaccard: 	0.39387134164010434
#    TP = 5437 TN = 395796 FP = 9 FN = 8358
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314/01-unet_result/314_r3c11.png
# 0.996078431372549
# 0.9500000000000001
# Results for r3c11.png                  (roi     - unet     - 0.98 accuracy)
#    Precision: 	0.9974085365853659
#    Recall/Sen: 	0.4324520819563781
#    F1/Dice: 	0.6033195020746889
#    Accuracy: 	0.978994140625
#    Specificity: 0.9999569042005729
#    Jaccard: 	0.43196672608437314
#    TP = 6543 TN = 394453 FP = 17 FN = 8587
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314/01-unet_result/314_r3c6.png
# 1.0
# 0.9500000000000001
# Results for r3c6.png                   (roi     - unet     - 0.99 accuracy)
#    Precision: 	0.97
#    Recall/Sen: 	0.24808184143222506
#    F1/Dice: 	0.3951120162932791
#    Accuracy: 	0.9883984375
#    Specificity: 0.9998809948827799
#    Jaccard: 	0.24619289340101522
#    TP = 1552 TN = 403296 FP = 48 FN = 4704
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314/01-unet_result/314_r3c8.png
# 0.996078431372549
# 0.9500000000000001
# Results for r3c8.png                   (roi     - unet     - 0.98 accuracy)
#    Precision: 	0.4400871459694989
#    Recall/Sen: 	0.2811864225291787
#    F1/Dice: 	0.34313341173396056
#    Accuracy: 	0.9754541015625
#    Specificity: 0.9916529464524397
#    Jaccard: 	0.20709779179810725
#    TP = 2626 TN = 396920 FP = 3341 FN = 6713
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314/01-unet_result/314_r4c11.png
# 0.996078431372549
# 0.9500000000000001
# Results for r4c11.png                  (roi     - unet     - 0.96 accuracy)
#    Precision: 	0.9932872253864931
#    Recall/Sen: 	0.2113578323161494
#    F1/Dice: 	0.3485491987579856
#    Accuracy: 	0.95543701171875
#    Specificity: 0.9999146177072525
#    Jaccard: 	0.2110563623789765
#    TP = 4883 TN = 386464 FP = 33 FN = 18220
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314/01-unet_result/314_r4c12.png
# 1.0
# 0.9500000000000001
# Results for r4c12.png                  (roi     - unet     - 0.99 accuracy)
#    Precision: 	0.9988913525498891
#    Recall/Sen: 	0.5314380087295033
#    F1/Dice: 	0.6937706937706938
#    Accuracy: 	0.99029052734375
#    Specificity: 0.9999875349955001
#    Jaccard: 	0.5311247347323744
#    TP = 4505 TN = 401118 FP = 5 FN = 3972
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314/01-unet_result/314_r4c6.png
# 0.996078431372549
# 0.9500000000000001
# Results for r4c6.png                   (roi     - unet     - 0.98 accuracy)
#    Precision: 	0.9952277657266811
#    Recall/Sen: 	0.3185668657130954
#    F1/Dice: 	0.4826425415527035
#    Accuracy: 	0.975986328125
#    Specificity: 0.9999443317020835
#    Jaccard: 	0.3180809761508597
#    TP = 4588 TN = 395176 FP = 22 FN = 9814
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314/01-unet_result/314_r5c11.png
# 0.996078431372549
# 0.9500000000000001
# Results for r5c11.png                  (roi     - unet     - 0.98 accuracy)
#    Precision: 	0.9682800751879699
#    Recall/Sen: 	0.32644169835234477
#    F1/Dice: 	0.48827014218009474
#    Accuracy: 	0.9789111328125
#    Specificity: 0.9996599290637217
#    Jaccard: 	0.32298769496042007
#    TP = 4121 TN = 396841 FP = 135 FN = 8503
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314/01-unet_result/314_r5c12.png
# 1.0
# 0.9500000000000001
# Results for r5c12.png                  (roi     - unet     - 0.98 accuracy)
#    Precision: 	1.0
#    Recall/Sen: 	0.46134380453752183
#    F1/Dice: 	0.6313966680599511
#    Accuracy: 	0.98492919921875
#    Specificity: 1.0
#    Jaccard: 	0.46134380453752183
#    TP = 5287 TN = 398140 FP = 0 FN = 6173
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314/01-unet_result/314_r5c5.png
# 0.996078431372549
# 0.9500000000000001
# Results for r5c5.png                   (roi     - unet     - 0.97 accuracy)
#    Precision: 	1.0
#    Recall/Sen: 	0.3998806488363262
#    F1/Dice: 	0.5713067741435437
#    Accuracy: 	0.9729931640625
#    Specificity: 1.0
#    Jaccard: 	0.3998806488363262
#    TP = 7371 TN = 391167 FP = 0 FN = 11062
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314/01-unet_result/314_r5c6.png
# 0.996078431372549
# 0.9500000000000001
# Results for r5c6.png                   (roi     - unet     - 0.99 accuracy)
#    Precision: 	0.9959677419354839
#    Recall/Sen: 	0.5233050847457628
#    F1/Dice: 	0.6861111111111112
#    Accuracy: 	0.9895166015625
#    Specificity: 0.999952574931608
#    Jaccard: 	0.5221987315010571
#    TP = 4693 TN = 400613 FP = 19 FN = 4275
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314/01-unet_result/314_r6c11.png
# 1.0
# 0.9500000000000001
# Results for r6c11.png                  (roi     - unet     - 0.99 accuracy)
#    Precision: 	0.9923562645397142
#    Recall/Sen: 	0.45546064673581454
#    F1/Dice: 	0.6243596445373758
#    Accuracy: 	0.99122802734375
#    Specificity: 0.9999429342702038
#    Jaccard: 	0.45386836905304756
#    TP = 2986 TN = 403021 FP = 23 FN = 3570
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314/01-unet_result/314_r6c12.png
# 1.0
# 0.9500000000000001
# Results for r6c12.png                  (roi     - unet     - 0.99 accuracy)
#    Precision: 	0.9980208708168405
#    Recall/Sen: 	0.6212341807593236
#    F1/Dice: 	0.765790018637399
#    Accuracy: 	0.99171630859375
#    Specificity: 0.9999725460539944
#    Jaccard: 	0.6204697986577181
#    TP = 5547 TN = 400660 FP = 11 FN = 3382
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314/01-unet_result/314_r6c5.png
# 0.996078431372549
# 0.9500000000000001
# Results for r6c5.png                   (roi     - unet     - 0.99 accuracy)
#    Precision: 	1.0
#    Recall/Sen: 	0.42107819329771734
#    F1/Dice: 	0.592617908407382
#    Accuracy: 	0.99126953125
#    Specificity: 1.0
#    Jaccard: 	0.42107819329771734
#    TP = 2601 TN = 403423 FP = 0 FN = 3576
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314/01-unet_result/314_r7c11.png
# 0.996078431372549
# 0.9500000000000001
# Results for r7c11.png                  (roi     - unet     - 0.99 accuracy)
#    Precision: 	1.0
#    Recall/Sen: 	0.6039883445638318
#    F1/Dice: 	0.75310814646608
#    Accuracy: 	0.98938232421875
#    Specificity: 1.0
#    Jaccard: 	0.6039883445638318
#    TP = 6633 TN = 398618 FP = 0 FN = 4349
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314/01-unet_result/314_r7c6.png
# 0.996078431372549
# 0.9500000000000001
# Results for r7c6.png                   (roi     - unet     - 0.98 accuracy)
#    Precision: 	0.5753835505825354
#    Recall/Sen: 	0.5133271585880416
#    F1/Dice: 	0.5425867507886435
#    Accuracy: 	0.9794677734375
#    Specificity: 0.9907948074811882
#    Jaccard: 	0.3722943722943723
#    TP = 4988 TN = 396202 FP = 3681 FN = 4729
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314/01-unet_result/314_r8c11.png
# 1.0
# 0.9500000000000001
# Results for r8c11.png                  (roi     - unet     - 0.99 accuracy)
#    Precision: 	0.998828010547905
#    Recall/Sen: 	0.3817041764640018
#    F1/Dice: 	0.5523331173039533
#    Accuracy: 	0.9865087890625
#    Specificity: 0.9999900166970741
#    Jaccard: 	0.38153329602686065
#    TP = 3409 TN = 400665 FP = 4 FN = 5522
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314/01-unet_result/314_r8c5.png
# 0.996078431372549
# 0.9500000000000001
# Results for r8c5.png                   (roi     - unet     - 0.98 accuracy)
#    Precision: 	0.9893196202531646
#    Recall/Sen: 	0.44027814452953085
#    F1/Dice: 	0.6093683376987269
#    Accuracy: 	0.98434326171875
#    Specificity: 0.9998644030343588
#    Jaccard: 	0.43819535698642137
#    TP = 5002 TN = 398185 FP = 54 FN = 6359
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314/01-unet_result/314_r8c6.png
# 0.996078431372549
# 0.9500000000000001
# Results for r8c6.png                   (roi     - unet     - 0.99 accuracy)
#    Precision: 	0.8863319386331938
#    Recall/Sen: 	0.48247500949006705
#    F1/Dice: 	0.624825891028267
#    Accuracy: 	0.98882080078125
#    Specificity: 0.998782664545665
#    Jaccard: 	0.45436129647283124
#    TP = 3813 TN = 401208 FP = 489 FN = 4090
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314/01-unet_result/314_r9c10.png
# 1.0
# 0.9500000000000001
# Results for r9c10.png                  (roi     - unet     - 0.97 accuracy)
#    Precision: 	1.0
#    Recall/Sen: 	0.1533318136919687
#    F1/Dice: 	0.2658936688846433
#    Accuracy: 	0.97279541015625
#    Specificity: 1.0
#    Jaccard: 	0.1533318136919687
#    TP = 2018 TN = 396439 FP = 0 FN = 11143
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314/01-unet_result/314_r9c5.png
# 0.996078431372549
# 0.9500000000000001
# Results for r9c5.png                   (roi     - unet     - 0.98 accuracy)
#    Precision: 	0.997906976744186
#    Recall/Sen: 	0.3107618771726535
#    F1/Dice: 	0.47393417274132976
#    Accuracy: 	0.9767431640625
#    Specificity: 0.9999772607834418
#    Jaccard: 	0.31055945574292537
#    TP = 4291 TN = 395783 FP = 9 FN = 9517
# -
# Patch results dir: ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314
# ../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/314/01-unet_result/314_r9c6.png
# 0.996078431372549
# 0.9500000000000001
# Results for r9c6.png                   (roi     - unet     - 0.97 accuracy)
#    Precision: 	0.9485023646873357
#    Recall/Sen: 	0.31354950781702373
#    F1/Dice: 	0.4712998825014143
#    Accuracy: 	0.97033935546875
#    Specificity: 0.9992506308464812
#    Jaccard: 	0.30830107037121385
#    TP = 5415 TN = 392036 FP = 294 FN = 11855
# -

# %%
import numpy as np
import pandas as pd
import os

dir = f'../../datasets/BONE_CHANNELS/results/TL_BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/pixels/'
files = os.listdir(dir)

means_matrix = np.zeros((20, 12))
for idx in range(len(files)):
    if os.path.isdir(dir + files[idx]):
        continue
    
    print(files[idx])
    my_data = np.genfromtxt(dir + files[idx], delimiter=',')

    my_data = np.delete(my_data, 0, 0)
    my_data = np.delete(my_data, 0, 1)
    my_data = np.delete(my_data, 0, 1)

    means_row = []
    for col in range(len(my_data[0,:])):
        means_row.append(np.sum(my_data[:,col])/(len(my_data[:,col])))

    means_matrix[idx,:] = np.array(means_row)

np.round(means_matrix, 3, means_matrix)
df = pd.DataFrame(means_matrix)
df['file'] = files
# Save DataFrame to .csv
df.to_csv(dir + 'means.csv', index=False, header=['auc', 'accuracy', 'precision', 'f1/dice', 'jaccard', 'sensitivity/recall', 'specificity', 'pixels', 'tp', 'tn', 'fp', 'fn', 'file'])
#print(means_matrix)
# Out:
# quantitative_analysis_0.000.csv
# quantitative_analysis_0.050.csv
# quantitative_analysis_0.100.csv
# quantitative_analysis_0.150.csv
# quantitative_analysis_0.200.csv
# quantitative_analysis_0.250.csv
# quantitative_analysis_0.300.csv
# quantitative_analysis_0.350.csv
# quantitative_analysis_0.400.csv
# quantitative_analysis_0.450.csv
# quantitative_analysis_0.500.csv
# quantitative_analysis_0.550.csv
# quantitative_analysis_0.600.csv
# quantitative_analysis_0.650.csv
# quantitative_analysis_0.700.csv
# quantitative_analysis_0.750.csv
# quantitative_analysis_0.800.csv
# quantitative_analysis_0.850.csv
# quantitative_analysis_0.900.csv
# quantitative_analysis_0.950.csv

# %% [markdown]
# ## Generate masks for best p (0.4)

# %%
import numpy as np
from PIL import Image
from scipy import ndimage
from skimage.measure import regionprops
import os
import matplotlib.pyplot as plt

def fill_contours(arr):
    return np.maximum.accumulate(arr,1) & np.maximum.accumulate(arr[:,::-1],1)[:,::-1]

def get_mean_props_area(RGBna):
    labeled, nr_objects = ndimage.label(RGBna != 0.) 
    props = regionprops(labeled)

    new_mask = np.copy(RGBna)
    mean_props_area = 0
    for prop in range(len(props)):
        mean_props_area = mean_props_area + props[prop].area
    
    mean_props_area = mean_props_area/len(props)
    return mean_props_area

# Remove ruídos  
def remove_noise(RGBna, mean_props_area):
    labeled, _ = ndimage.label(RGBna != 0.) 
    props = regionprops(labeled)

    new_mask = np.copy(RGBna)
    
    for prop in range(len(props)):
        if props[prop].area > (0.1)*mean_props_area:
            continue
        else:
            [X, Y, x, y] = props[prop].bbox
            new_mask[X:x, Y:y] = props[prop].image_filled.astype(np.uint8)*0
       
            
    #plt.imshow(new_mask)#Image.fromarray(new_mask).show()
    return new_mask

# Preenche contornos  
def fill_components_contours(RGBna):
    labeled, nr_objects = ndimage.label(RGBna != 0.) 
    props = regionprops(labeled)

    new_mask = np.copy(RGBna)

    for prop in range(len(props)):
        [X, Y, x, y] = props[prop].bbox
        new_mask[X:x, Y:y] = fill_contours(props[prop].image_filled.astype(np.uint8)*255)

    return new_mask

# %%
threshold_prob = 0.4

for batch_idx, (data, target, fname, original_size) in enumerate(dataloaders['test']):
    # wsi image number
    wsi_image_number = fname[0].split("_")[0]
    if wsi_image_number not in wsi_tissue_patches:
        # extract the tissue region from original image and draw the heat grid
        wsi_image_path = "{}/{}.png".format(wsi_images_dir_tumor, wsi_image_number)
        wsi_image = open_wsi(wsi_image_path)
        pil_scaled_down_image = scale_down_wsi(wsi_image, magnification, False)
        np_scaled_down_image = pil_to_np(pil_scaled_down_image)
        # extract tissue region 
        np_tissue_mask, np_masked_image = extract_normal_region_from_wsi(wsi_image_path, np_scaled_down_image, None)
        pil_masked_image = np_to_pil(np_masked_image)
        # draw the heat grid
        pil_img_result, heat_grid, number_of_tiles = draw_heat_grid(np_masked_image, tile_size)
        tissue_patches = []
        for idx, (position, row, column, location, size, color) in enumerate(heat_grid):
            if color != GREEN_COLOR: 
                tissue_patches.append("{}_r{}c{}.png".format(wsi_image_number, row, column))
        wsi_tissue_patches[wsi_image_number] = tissue_patches
        #print(wsi_tissue_patches)
    # check if the patch was excluded in preprocessing step
    patch_excludde_in_preprocessing = fname[0] not in wsi_tissue_patches[wsi_image_number]
    # load the mask image
    mask_np_img = target[0].numpy()
    # roi x non_roi classes
    wsi_class = class_name if wsi_image_path.find(class_name) > 0 else "normal"
    patch_class = "roi" if np.max(np.unique(mask_np_img)) > 0 else 'non_roi'
    # load the predicted image result
    patch_results_dir = "{}/{}/patch/{}x{}/{}".format(results_dir, wsi_class, patch_size, patch_size, fname[0])
    print("Patch results dir: " + patch_results_dir)
    unet_result_img = "{}/01-unet_result/{}".format(patch_results_dir, fname[0])
    predicted_pil_img = Image.fromarray(np.zeros(mask_np_img.shape)) if patch_excludde_in_preprocessing else load_pil_image(unet_result_img, gray=True) if os.path.isfile(unet_result_img) else Image.fromarray(np.zeros(mask_np_img.shape))
    predicted_np_img = np.copy(pil_to_np(predicted_pil_img)) 
    predicted_np_img = predicted_np_img * (1.0/255)
    predicted_np_img = basic_threshold(predicted_np_img, threshold=threshold_prob, output_type="float")
    
    # SAVE BINARY IMAGES
    bin_images_path = '../../datasets/BONE_CHANNELS/results/BONE_CHANNELS__Size-640x640_Epoch-100_Images-464_Batch-1__random_distortion/testing/bones/patch/640x640/binary_images/'
    predicted_np_img_255 = predicted_np_img * 255
    mean = get_mean_props_area(predicted_np_img_255)
    predicted_np_img_255 = remove_noise(predicted_np_img_255, mean)
    predicted_np_img_255 = fill_components_contours(predicted_np_img_255)
    
    new_p = Image.fromarray(predicted_np_img_255)
    if new_p.mode != 'RGB':
        new_p = new_p.convert('RGB')
    new_p.save(bin_images_path + fname[0])

# %% [markdown]
# # Quantitative metrics for image-patches (512x512)

# %%
import os
import sys
import csv

from scipy import ndimage as nd
from skimage import measure



current_path = os.path.abspath('.')
root_path = os.path.dirname(os.path.dirname(current_path))
sys.path.append(root_path)

from sourcecode.ORCA.orca_dataloader_512x512 import *
from sourcecode.wsi_image_utils import *
from sourcecode.evaluation_utils import *



dataset_dir = "../../datasets/ORCA_512x512"
dataset_dir_results = "/media/dalifreire/DADOS/PhD/github/tumor_regions_segmentation/datasets/ORCA_512x512"

batch_size = 1
patch_size = (512, 512)
color_model = "LAB"
dataloaders = create_dataloader(batch_size=batch_size, 
                                shuffle=False,
                                dataset_dir=dataset_dir,
                                color_model=color_model)

dataset_train_size = len(dataloaders['train'].dataset)
dataset_test_size = len(dataloaders['test'].dataset)
print("-")

tile_size = 20
magnification=0.625

threshold_prob = 0.50
threshold_itc = 200/(0.243 * pow(2, 5))

wsi_images_dir_normal = "{}/testing/normal/wsi".format(dataset_dir)
wsi_images_dir_tumor = "{}/testing/tumor/wsi".format(dataset_dir)

trained_model_version = "ORCA__Size-512x512_Epoch-352_Images-80_Batch-1__one_by_epoch"
results_dir="{}/results/{}/testing".format(dataset_dir_results, trained_model_version)
csv_file_path = "{}/quantitative_analysis_{}.csv".format(results_dir, threshold_prob)

wsi_tissue_patches = {}
with open(csv_file_path, mode='w') as medidas_file:

    medidas_writer = csv.writer(medidas_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    medidas_writer.writerow(['wsi_image', 'patch_image', 'class', 'auc', 'accuracy', 'precision', 'f1/dice', 'jaccard', 'sensitivity/recall', 'specificity', 'pixels', 'tp', 'tn', 'fp', 'fn'])

    for batch_idx, (data, target, fname, original_size) in enumerate(dataloaders['test']):
        
        # load the mask image
        mask_np_img = target[0].numpy()

        # roi x non_roi classes
        wsi_class = class_name
        patch_class = "roi"                

        # load the predicted image result
        patch_results_dir = "{}/{}/patch/{}x{}/{}".format(results_dir, wsi_class, patch_size[0], patch_size[1], fname[0])
        unet_result_img = "{}/01-unet_result/{}".format(patch_results_dir, fname[0])
        predicted_pil_img = load_pil_image(unet_result_img, gray=True) if os.path.isfile(unet_result_img) else Image.fromarray(np.zeros(mask_np_img.shape))
        predicted_np_img = np.copy(pil_to_np(predicted_pil_img))
        predicted_np_img = predicted_np_img * (1.0/255)
        predicted_np_img = basic_threshold(predicted_np_img, threshold=threshold_prob, output_type="uint8")

        predicted_labels = measure.label(predicted_np_img, connectivity=2)
        predicted_np_img = np.zeros((predicted_np_img.shape[0], predicted_np_img.shape[1]))
        labels = np.unique(predicted_labels)
        properties = measure.regionprops(predicted_labels)
        for lbl in range(1, np.max(labels)):
            major_axis_length = properties[lbl-1].major_axis_length
            if major_axis_length > threshold_itc:
                predicted_np_img[predicted_labels == lbl] = 1


        # metrics
        auc = roc_auc_score(mask_np_img, predicted_np_img)
        precision = precision_score(mask_np_img, predicted_np_img)
        recall = recall_score(mask_np_img, predicted_np_img)
        accuracy = accuracy_score(mask_np_img, predicted_np_img)
        f1 = f1_score(mask_np_img, predicted_np_img)
        specificity = specificity_score(mask_np_img, predicted_np_img)
        jaccard = jaccard_score(mask_np_img, predicted_np_img)

        total_pixels, tn, fp, fn, tp = tn_fp_fn_tp(mask_np_img, predicted_np_img)

        print(fname[0])
        print("Results for {:26} ({:7} - {:8} - {:04.2f} accuracy)".format(fname[0], patch_class, "unet", accuracy))
        #print("   Precision: \t{}".format(precision))
        #print("   Recall/Sen: \t{}".format(recall))
        #print("   F1/Dice: \t{}".format(f1))
        #print("   Accuracy: \t{}".format(accuracy))
        #print("   Specificity: {}".format(specificity))
        #print("   Jaccard: \t{}".format(jaccard))
        #print("   TP = {} TN = {} FP = {} FN = {}".format(tp, tn, fp, fn))
        #print("-")

        medidas_writer.writerow([fname[0], '-', patch_class, auc, accuracy, precision, f1, jaccard, recall, specificity, total_pixels, tp, tn, fp, fn])
