# %% [markdown]
# # Extracts the image-patches dataset

# %%
import os
os.environ['PATH'] = "C:\\Users\\Igor\\openslide-win64-20171122\\bin" + ";" + os.environ['PATH']
os.add_dll_directory("C:\\Users\\Igor\\openslide-win64-20171122\\bin")

from bones_dataloader import *

magnification=0.625
scale = get_scale_by_magnification(magnification)
tile_size=20
tile_size_original = int(scale * tile_size)
patch_size = 640

cls = "bones"
dataset_types = ["training"]
for dataset_type in sorted(dataset_types):
    
    logger.info("{} images".format(dataset_type))
    
    orca_dir = "../../datasets/BONE_CHANNELS"
    annotations_dir = "{}/{}/annotations".format(orca_dir, dataset_type)
    wsi_images_dir = "{}/{}/{}/".format(orca_dir, dataset_type, cls)
    patch_images_dir = "{}/{}/{}/patch/{}x{}".format(orca_dir, dataset_type, cls, patch_size, patch_size)
    
    for r, d, f in sorted(os.walk(wsi_images_dir)):
        for wsi_file in sorted(f):
            
            wsi_image_file = "{}/{}".format(r, wsi_file)
            wsi_image_number = wsi_file.replace(".png", "")
            
            file_is_png = wsi_image_file.lower().endswith('.png')
            if file_is_png:

                logger.info("Processing tma '{}'".format(wsi_file))
                
                # check directory to save image-patches
                dir_to_save = "{}/{}".format(patch_images_dir, wsi_image_number)
                if not os.path.exists(dir_to_save):
                    os.makedirs("{}/01-roi/01-original".format(dir_to_save))
                    os.makedirs("{}/01-roi/02-mask".format(dir_to_save))
                    os.makedirs("{}/01-roi/03-roi".format(dir_to_save))             
                    os.makedirs("{}/02-non_roi/01-original".format(dir_to_save))
                    os.makedirs("{}/02-non_roi/02-mask".format(dir_to_save))
                
                # tumor annotations mask
                annotation_file = "{}/{}.png".format(annotations_dir, wsi_image_number)
                wsi_mask_pil = load_pil_image(annotation_file, gray=True)
                
                # tumor tissue region
                wsi_image = open_wsi(wsi_image_file)
                max_w, max_h = wsi_image.dimensions
                wsi_image_pil = load_pil_image(wsi_image_file, gray=False)
                pil_scaled_down_image = scale_down_wsi(wsi_image, magnification, False)
                
                np_tumor_mask = np.zeros((wsi_mask_pil.size[0], wsi_mask_pil.size[1]), dtype=bool)
                np_tumor_mask[pil_to_np(wsi_mask_pil) == 255] = True
                pil_tumor_mask = np_to_pil(np_tumor_mask)
                
                np_normal_mask = np.zeros((wsi_mask_pil.size[0], wsi_mask_pil.size[1]), dtype=bool)
                np_normal_mask[pil_to_np(wsi_mask_pil) < 255] = True
                np_normal_mask[pil_to_np(wsi_mask_pil) == 0] = False
                pil_normal_mask = np_to_pil(np_normal_mask)
                
                pil_background = np_to_pil(np_normal_mask | np_tumor_mask)

                wsi_image_np = pil_to_np(wsi_image_pil)
                np_tumor_masked = mask_rgb(wsi_image_np, np_tumor_mask)
                np_tumor_masked = image_resize(np_tumor_masked, height=pil_scaled_down_image.size[1])
                pil_tumor_masked = np_to_pil(np_tumor_masked)
                
                np_normal_masked = mask_rgb(wsi_image_np, np_normal_mask)
                np_normal_masked = image_resize(np_normal_masked, height=pil_scaled_down_image.size[1])
                pil_normal_masked = np_to_pil(np_normal_masked)

                blend_tumor = blend_image(wsi_image_pil, pil_tumor_mask, foreground='red', inverse=True)
                blend_tissue = blend_image(blend_tumor, pil_normal_mask, foreground='green', inverse=True)
                blend_background = blend_image(blend_tissue, pil_background, foreground='blue', inverse=False).resize(pil_tumor_masked.size, Image.ANTIALIAS)

                pil_scaled_down_image.save('{}/{}_1.png'.format(dir_to_save, wsi_image_number))
                blend_background.save('{}/{}_2.png'.format(dir_to_save, wsi_image_number))
                pil_normal_masked.save('{}/{}_3.png'.format(dir_to_save, wsi_image_number))
                pil_tumor_masked.save('{}/{}_4.png'.format(dir_to_save, wsi_image_number))
                
                #heat grid normal
                pil_img_normal_result, heat_grid_normal, number_of_tiles_normal = draw_heat_grid(np_normal_masked, tile_size)
                pil_img_normal_result.save('{}/{}_5.png'.format(dir_to_save, wsi_image_number))

                # heat grid tumor
                pil_img_result, heat_grid, number_of_tiles = draw_heat_grid(np_tumor_masked, tile_size)
                pil_img_result.save('{}/{}_6.png'.format(dir_to_save, wsi_image_number))
                
                used_patches = set()                
                tiles_tumor_tissue = []
                tiles_normal_tissue = []
                tiles_background = []
                for idx, (position, row, column, location, size, color) in enumerate(heat_grid):

                    tile = (position, row, column, location, size, color)                    
                    if color == YELLOW_COLOR or color == ORANGE_COLOR or color == RED_COLOR:
                        tiles_tumor_tissue.append(tile)
                        used_patches.add("r{}c{}".format(row, column))
                
                for idx, (position, row, column, location, size, color) in enumerate(heat_grid_normal):

                    name = "r{}c{}".format(row, column)
                    tile = (position, row, column, location, size, color)
                    if name not in used_patches:
                        if color == GREEN_COLOR:
                            tiles_background.append(tile)
                        else:
                            tiles_normal_tissue.append(tile)
                
                logger.info("\t {} patches of {}x{} size.".format(len(heat_grid_normal), patch_size, patch_size))
                logger.info("\t\t {} patches of {}x{} (normal tissue).".format(len(tiles_normal_tissue), patch_size, patch_size))
                logger.info("\t\t {} patches of {}x{} (tumor tissue).".format(len(tiles_tumor_tissue), patch_size, patch_size))
                logger.info("\t\t {} patches of {}x{} (background).".format(len(tiles_background), patch_size, patch_size))
                
                
                # extract and save normal patches
                for (position, row, column, location, size, color) in tiles_normal_tissue:
                    
                    r_s = row * tile_size_original
                    r_e = r_s + (tile_size_original if (r_s + tile_size_original) <= max_w else (max_w - r_s))
                    c_s = column * tile_size_original
                    c_e = c_s + (tile_size_original if (c_s + tile_size_original) <= max_h else (max_h - c_s))
                    
                    np_tile_mask = np.zeros((tile_size_original, tile_size_original), dtype=bool)
                    np_tile_mask[0:(r_e-r_s), 0:(c_e-c_s)] = np_tumor_mask[r_s:r_e, c_s:c_e]
                    
                    # only tile with valid size
                    #if np_tile_mask.shape[0] == tile_size_original and np_tile_mask.shape[1] == tile_size_original:

                    tile_pil, tile_np = read_region(wsi_image_file, column, row, magnification, tile_size)
                    left = (column * tile_size_original)
                    top = (row * tile_size_original)

                    pil_mask = np_to_pil(np.zeros((tile_np.shape[0], tile_np.shape[1]), dtype=np.uint8))
                    np_tile_mask = pil_to_np(pil_mask).astype(bool)

                    # save the extracted normal tile
                    tile_pil.save('{}/02-non_roi/{}/{}_r{}c{}.png'.format(dir_to_save, "01-original", wsi_image_number, row, column))
                    np_to_pil(np_tile_mask).save('{}/02-non_roi/{}/{}_r{}c{}.png'.format(dir_to_save, "02-mask", wsi_image_number, row, column))

                # extract and save tumor patches
                for (position, row, column, location, size, color) in tiles_tumor_tissue:
                    
                    r_s = row * tile_size_original
                    r_e = r_s + (tile_size_original if (r_s + tile_size_original) <= max_w else (max_w - r_s))
                    c_s = column * tile_size_original
                    c_e = c_s + (tile_size_original if (c_s + tile_size_original) <= max_h else (max_h - c_s))
                    
                    np_tile_mask = np.zeros((tile_size_original, tile_size_original), dtype=bool)
                    np_tile_mask[0:(r_e-r_s), 0:(c_e-c_s)] = np_tumor_mask[r_s:r_e, c_s:c_e]
                    
                    # only tile with valid size
                    #if np_tile_mask.shape[0] == tile_size_original and np_tile_mask.shape[1] == tile_size_original:

                    tile_pil, tile_np = read_region(wsi_image_file, column, row, magnification, tile_size)
                    left = (column * tile_size_original)
                    top = (row * tile_size_original)
                    
                    pil_tile_roi = blend_image(np_to_pil(tile_np), np_to_pil(np_tile_mask), foreground='blue', inverse=True)
                    #pil_tile_roi = blend_image(pil_tile_roi, np_to_pil(np_tile_mask), foreground='green', inverse=False)

                     # save the extracted tumor image-patch
                    tile_pil.save('{}/01-roi/{}/{}_r{}c{}.png'.format(dir_to_save, "01-original", wsi_image_number, row, column))
                    np_to_pil(np_tile_mask).save('{}/01-roi/{}/{}_r{}c{}.png'.format(dir_to_save, "02-mask", wsi_image_number, row, column))
                    pil_tile_roi.save('{}/01-roi/{}/{}_r{}c{}.png'.format(dir_to_save, "03-roi", wsi_image_number, row, column))
# Out:
# 2023-09-10 19:58:56,745 :: INFO <module> :: training images
# 2023-09-10 19:58:56,746 :: INFO <module> :: Processing tma '205.png'
# C:\Users\Igor\AppData\Local\Temp\ipykernel_18616\2190959294.py:76: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   blend_background = blend_image(blend_tissue, pil_background, foreground='blue', inverse=False).resize(pil_tumor_masked.size, Image.ANTIALIAS)
# 2023-09-10 19:59:03,524 :: INFO <module> :: 	 196 patches of 640x640 size.
# 2023-09-10 19:59:03,525 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 19:59:03,525 :: INFO <module> :: 		 27 patches of 640x640 (tumor tissue).
# 2023-09-10 19:59:03,525 :: INFO <module> :: 		 169 patches of 640x640 (background).
# 2023-09-10 19:59:41,017 :: INFO <module> :: Processing tma '206.png'
# 2023-09-10 19:59:46,703 :: INFO <module> :: 	 169 patches of 640x640 size.
# 2023-09-10 19:59:46,704 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 19:59:46,704 :: INFO <module> :: 		 27 patches of 640x640 (tumor tissue).
# 2023-09-10 19:59:46,705 :: INFO <module> :: 		 142 patches of 640x640 (background).
# 2023-09-10 20:00:24,958 :: INFO <module> :: Processing tma '207.png'
# 2023-09-10 20:00:30,223 :: INFO <module> :: 	 144 patches of 640x640 size.
# 2023-09-10 20:00:30,224 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:00:30,225 :: INFO <module> :: 		 27 patches of 640x640 (tumor tissue).
# 2023-09-10 20:00:30,225 :: INFO <module> :: 		 117 patches of 640x640 (background).
# 2023-09-10 20:01:06,350 :: INFO <module> :: Processing tma '208.png'
# 2023-09-10 20:01:11,428 :: INFO <module> :: 	 144 patches of 640x640 size.
# 2023-09-10 20:01:11,428 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:01:11,429 :: INFO <module> :: 		 28 patches of 640x640 (tumor tissue).
# 2023-09-10 20:01:11,430 :: INFO <module> :: 		 116 patches of 640x640 (background).
# 2023-09-10 20:01:47,736 :: INFO <module> :: Processing tma '209.png'
# 2023-09-10 20:01:53,910 :: INFO <module> :: 	 169 patches of 640x640 size.
# 2023-09-10 20:01:53,910 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:01:53,911 :: INFO <module> :: 		 27 patches of 640x640 (tumor tissue).
# 2023-09-10 20:01:53,912 :: INFO <module> :: 		 142 patches of 640x640 (background).
# 2023-09-10 20:02:33,525 :: INFO <module> :: Processing tma '210.png'
# 2023-09-10 20:02:39,555 :: INFO <module> :: 	 169 patches of 640x640 size.
# 2023-09-10 20:02:39,555 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:02:39,556 :: INFO <module> :: 		 28 patches of 640x640 (tumor tissue).
# 2023-09-10 20:02:39,556 :: INFO <module> :: 		 141 patches of 640x640 (background).
# 2023-09-10 20:03:20,515 :: INFO <module> :: Processing tma '212.png'
# 2023-09-10 20:03:26,626 :: INFO <module> :: 	 169 patches of 640x640 size.
# 2023-09-10 20:03:26,626 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:03:26,627 :: INFO <module> :: 		 25 patches of 640x640 (tumor tissue).
# 2023-09-10 20:03:26,628 :: INFO <module> :: 		 144 patches of 640x640 (background).
# 2023-09-10 20:04:04,693 :: INFO <module> :: Processing tma '213.png'
# 2023-09-10 20:04:12,057 :: INFO <module> :: 	 225 patches of 640x640 size.
# 2023-09-10 20:04:12,057 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:04:12,058 :: INFO <module> :: 		 26 patches of 640x640 (tumor tissue).
# 2023-09-10 20:04:12,058 :: INFO <module> :: 		 199 patches of 640x640 (background).
# 2023-09-10 20:04:55,102 :: INFO <module> :: Processing tma '214.png'
# 2023-09-10 20:05:00,693 :: INFO <module> :: 	 169 patches of 640x640 size.
# 2023-09-10 20:05:00,694 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:05:00,694 :: INFO <module> :: 		 29 patches of 640x640 (tumor tissue).
# 2023-09-10 20:05:00,695 :: INFO <module> :: 		 140 patches of 640x640 (background).
# 2023-09-10 20:05:39,069 :: INFO <module> :: Processing tma '215.png'
# 2023-09-10 20:05:45,462 :: INFO <module> :: 	 196 patches of 640x640 size.
# 2023-09-10 20:05:45,463 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:05:45,464 :: INFO <module> :: 		 27 patches of 640x640 (tumor tissue).
# 2023-09-10 20:05:45,465 :: INFO <module> :: 		 169 patches of 640x640 (background).
# 2023-09-10 20:06:24,939 :: INFO <module> :: Processing tma '216.png'
# 2023-09-10 20:06:30,785 :: INFO <module> :: 	 169 patches of 640x640 size.
# 2023-09-10 20:06:30,786 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:06:30,787 :: INFO <module> :: 		 30 patches of 640x640 (tumor tissue).
# 2023-09-10 20:06:30,787 :: INFO <module> :: 		 139 patches of 640x640 (background).
# 2023-09-10 20:07:14,476 :: INFO <module> :: Processing tma '217.png'
# 2023-09-10 20:07:19,334 :: INFO <module> :: 	 144 patches of 640x640 size.
# 2023-09-10 20:07:19,334 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:07:19,336 :: INFO <module> :: 		 27 patches of 640x640 (tumor tissue).
# 2023-09-10 20:07:19,336 :: INFO <module> :: 		 117 patches of 640x640 (background).
# 2023-09-10 20:07:52,094 :: INFO <module> :: Processing tma '218.png'
# 2023-09-10 20:07:57,965 :: INFO <module> :: 	 169 patches of 640x640 size.
# 2023-09-10 20:07:57,966 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:07:57,967 :: INFO <module> :: 		 25 patches of 640x640 (tumor tissue).
# 2023-09-10 20:07:57,967 :: INFO <module> :: 		 144 patches of 640x640 (background).
# 2023-09-10 20:08:31,976 :: INFO <module> :: Processing tma '219.png'
# 2023-09-10 20:08:37,680 :: INFO <module> :: 	 169 patches of 640x640 size.
# 2023-09-10 20:08:37,681 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:08:37,682 :: INFO <module> :: 		 27 patches of 640x640 (tumor tissue).
# 2023-09-10 20:08:37,683 :: INFO <module> :: 		 142 patches of 640x640 (background).
# 2023-09-10 20:09:14,959 :: INFO <module> :: Processing tma '220.png'
# 2023-09-10 20:09:19,867 :: INFO <module> :: 	 144 patches of 640x640 size.
# 2023-09-10 20:09:19,867 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:09:19,868 :: INFO <module> :: 		 31 patches of 640x640 (tumor tissue).
# 2023-09-10 20:09:19,869 :: INFO <module> :: 		 113 patches of 640x640 (background).
# 2023-09-10 20:09:57,105 :: INFO <module> :: Processing tma '221.png'
# 2023-09-10 20:10:01,785 :: INFO <module> :: 	 144 patches of 640x640 size.
# 2023-09-10 20:10:01,786 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:10:01,787 :: INFO <module> :: 		 25 patches of 640x640 (tumor tissue).
# 2023-09-10 20:10:01,787 :: INFO <module> :: 		 119 patches of 640x640 (background).
# 2023-09-10 20:10:30,563 :: INFO <module> :: Processing tma '222.png'
# 2023-09-10 20:10:35,860 :: INFO <module> :: 	 169 patches of 640x640 size.
# 2023-09-10 20:10:35,861 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:10:35,861 :: INFO <module> :: 		 31 patches of 640x640 (tumor tissue).
# 2023-09-10 20:10:35,862 :: INFO <module> :: 		 138 patches of 640x640 (background).
# 2023-09-10 20:11:14,442 :: INFO <module> :: Processing tma '315.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (104244100 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2023-09-10 20:11:23,255 :: INFO <module> :: 	 256 patches of 640x640 size.
# 2023-09-10 20:11:23,256 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:11:23,256 :: INFO <module> :: 		 40 patches of 640x640 (tumor tissue).
# 2023-09-10 20:11:23,257 :: INFO <module> :: 		 216 patches of 640x640 (background).
# 2023-09-10 20:12:34,293 :: INFO <module> :: Processing tma '316.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (118548544 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2023-09-10 20:12:44,049 :: INFO <module> :: 	 289 patches of 640x640 size.
# 2023-09-10 20:12:44,050 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:12:44,050 :: INFO <module> :: 		 39 patches of 640x640 (tumor tissue).
# 2023-09-10 20:12:44,051 :: INFO <module> :: 		 250 patches of 640x640 (background).
# 2023-09-10 20:13:57,613 :: INFO <module> :: Processing tma '317.png'
# 2023-09-10 20:14:07,514 :: INFO <module> :: 	 289 patches of 640x640 size.
# 2023-09-10 20:14:07,514 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:14:07,515 :: INFO <module> :: 		 35 patches of 640x640 (tumor tissue).
# 2023-09-10 20:14:07,515 :: INFO <module> :: 		 254 patches of 640x640 (background).
# 2023-09-10 20:15:16,161 :: INFO <module> :: Processing tma '318.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (126337600 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2023-09-10 20:15:26,941 :: INFO <module> :: 	 324 patches of 640x640 size.
# 2023-09-10 20:15:26,941 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:15:26,942 :: INFO <module> :: 		 33 patches of 640x640 (tumor tissue).
# 2023-09-10 20:15:26,942 :: INFO <module> :: 		 291 patches of 640x640 (background).
# 2023-09-10 20:16:37,279 :: INFO <module> :: Processing tma '319.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (123921424 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2023-09-10 20:16:47,358 :: INFO <module> :: 	 324 patches of 640x640 size.
# 2023-09-10 20:16:47,359 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:16:47,360 :: INFO <module> :: 		 28 patches of 640x640 (tumor tissue).
# 2023-09-10 20:16:47,360 :: INFO <module> :: 		 296 patches of 640x640 (background).
# 2023-09-10 20:17:39,998 :: INFO <module> :: Processing tma '320.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (134977924 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2023-09-10 20:17:50,919 :: INFO <module> :: 	 361 patches of 640x640 size.
# 2023-09-10 20:17:50,920 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:17:50,921 :: INFO <module> :: 		 38 patches of 640x640 (tumor tissue).
# 2023-09-10 20:17:50,921 :: INFO <module> :: 		 323 patches of 640x640 (background).
# 2023-09-10 20:19:08,007 :: INFO <module> :: Processing tma '321.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (122722084 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2023-09-10 20:19:18,265 :: INFO <module> :: 	 324 patches of 640x640 size.
# 2023-09-10 20:19:18,266 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:19:18,266 :: INFO <module> :: 		 32 patches of 640x640 (tumor tissue).
# 2023-09-10 20:19:18,267 :: INFO <module> :: 		 292 patches of 640x640 (background).
# 2023-09-10 20:20:20,331 :: INFO <module> :: Processing tma '322.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (123121216 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2023-09-10 20:20:30,173 :: INFO <module> :: 	 324 patches of 640x640 size.
# 2023-09-10 20:20:30,174 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:20:30,175 :: INFO <module> :: 		 28 patches of 640x640 (tumor tissue).
# 2023-09-10 20:20:30,175 :: INFO <module> :: 		 296 patches of 640x640 (background).
# 2023-09-10 20:21:20,340 :: INFO <module> :: Processing tma '323.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (147185424 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2023-09-10 20:21:31,931 :: INFO <module> :: 	 361 patches of 640x640 size.
# 2023-09-10 20:21:31,931 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:21:31,932 :: INFO <module> :: 		 27 patches of 640x640 (tumor tissue).
# 2023-09-10 20:21:31,933 :: INFO <module> :: 		 334 patches of 640x640 (background).
# 2023-09-10 20:22:26,211 :: INFO <module> :: Processing tma '324.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (110292004 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2023-09-10 20:22:35,016 :: INFO <module> :: 	 289 patches of 640x640 size.
# 2023-09-10 20:22:35,016 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:22:35,017 :: INFO <module> :: 		 42 patches of 640x640 (tumor tissue).
# 2023-09-10 20:22:35,018 :: INFO <module> :: 		 247 patches of 640x640 (background).
# 2023-09-10 20:23:43,513 :: INFO <module> :: Processing tma '325.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (137499076 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2023-09-10 20:23:54,407 :: INFO <module> :: 	 361 patches of 640x640 size.
# 2023-09-10 20:23:54,408 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:23:54,409 :: INFO <module> :: 		 31 patches of 640x640 (tumor tissue).
# 2023-09-10 20:23:54,409 :: INFO <module> :: 		 330 patches of 640x640 (background).
# 2023-09-10 20:24:54,655 :: INFO <module> :: Processing tma '326.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (105596176 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2023-09-10 20:25:03,269 :: INFO <module> :: 	 289 patches of 640x640 size.
# 2023-09-10 20:25:03,270 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:25:03,271 :: INFO <module> :: 		 33 patches of 640x640 (tumor tissue).
# 2023-09-10 20:25:03,271 :: INFO <module> :: 		 256 patches of 640x640 (background).
# 2023-09-10 20:25:59,255 :: INFO <module> :: Processing tma '327.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (127351225 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2023-09-10 20:26:09,567 :: INFO <module> :: 	 324 patches of 640x640 size.
# 2023-09-10 20:26:09,568 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:26:09,568 :: INFO <module> :: 		 35 patches of 640x640 (tumor tissue).
# 2023-09-10 20:26:09,569 :: INFO <module> :: 		 289 patches of 640x640 (background).
# 2023-09-10 20:27:17,674 :: INFO <module> :: Processing tma '328.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (106523041 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2023-09-10 20:27:26,448 :: INFO <module> :: 	 289 patches of 640x640 size.
# 2023-09-10 20:27:26,448 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:27:26,449 :: INFO <module> :: 		 36 patches of 640x640 (tumor tissue).
# 2023-09-10 20:27:26,449 :: INFO <module> :: 		 253 patches of 640x640 (background).
# 2023-09-10 20:28:30,688 :: INFO <module> :: Processing tma '330.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (111598096 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2023-09-10 20:28:39,711 :: INFO <module> :: 	 289 patches of 640x640 size.
# 2023-09-10 20:28:39,712 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:28:39,712 :: INFO <module> :: 		 34 patches of 640x640 (tumor tissue).
# 2023-09-10 20:28:39,713 :: INFO <module> :: 		 255 patches of 640x640 (background).
# 2023-09-10 20:29:40,959 :: INFO <module> :: Processing tma '331.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (108784900 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2023-09-10 20:29:49,762 :: INFO <module> :: 	 289 patches of 640x640 size.
# 2023-09-10 20:29:49,762 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:29:49,763 :: INFO <module> :: 		 37 patches of 640x640 (tumor tissue).
# 2023-09-10 20:29:49,763 :: INFO <module> :: 		 252 patches of 640x640 (background).
# 2023-09-10 20:30:53,125 :: INFO <module> :: Processing tma '332.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (99960004 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2023-09-10 20:31:01,467 :: INFO <module> :: 	 256 patches of 640x640 size.
# 2023-09-10 20:31:01,468 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:31:01,469 :: INFO <module> :: 		 38 patches of 640x640 (tumor tissue).
# 2023-09-10 20:31:01,469 :: INFO <module> :: 		 218 patches of 640x640 (background).
# 2023-09-10 20:32:04,782 :: INFO <module> :: Processing tma '333.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (104325796 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2023-09-10 20:32:13,400 :: INFO <module> :: 	 256 patches of 640x640 size.
# 2023-09-10 20:32:13,401 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:32:13,402 :: INFO <module> :: 		 29 patches of 640x640 (tumor tissue).
# 2023-09-10 20:32:13,403 :: INFO <module> :: 		 227 patches of 640x640 (background).
# 2023-09-10 20:33:05,648 :: INFO <module> :: Processing tma '334.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (99940009 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2023-09-10 20:33:13,918 :: INFO <module> :: 	 256 patches of 640x640 size.
# 2023-09-10 20:33:13,919 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:33:13,920 :: INFO <module> :: 		 32 patches of 640x640 (tumor tissue).
# 2023-09-10 20:33:13,921 :: INFO <module> :: 		 224 patches of 640x640 (background).
# 2023-09-10 20:34:06,049 :: INFO <module> :: Processing tma '335.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (96727225 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2023-09-10 20:34:14,145 :: INFO <module> :: 	 256 patches of 640x640 size.
# 2023-09-10 20:34:14,146 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:34:14,147 :: INFO <module> :: 		 34 patches of 640x640 (tumor tissue).
# 2023-09-10 20:34:14,147 :: INFO <module> :: 		 222 patches of 640x640 (background).
# 2023-09-10 20:35:09,798 :: INFO <module> :: Processing tma '336.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (111049444 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2023-09-10 20:35:19,036 :: INFO <module> :: 	 289 patches of 640x640 size.
# 2023-09-10 20:35:19,036 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:35:19,037 :: INFO <module> :: 		 29 patches of 640x640 (tumor tissue).
# 2023-09-10 20:35:19,037 :: INFO <module> :: 		 260 patches of 640x640 (background).
# 2023-09-10 20:36:13,169 :: INFO <module> :: Processing tma '337.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (116014441 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2023-09-10 20:36:22,353 :: INFO <module> :: 	 289 patches of 640x640 size.
# 2023-09-10 20:36:22,353 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:36:22,354 :: INFO <module> :: 		 24 patches of 640x640 (tumor tissue).
# 2023-09-10 20:36:22,354 :: INFO <module> :: 		 265 patches of 640x640 (background).
# 2023-09-10 20:37:04,316 :: INFO <module> :: Processing tma '338.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (109788484 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2023-09-10 20:37:13,194 :: INFO <module> :: 	 289 patches of 640x640 size.
# 2023-09-10 20:37:13,195 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:37:13,195 :: INFO <module> :: 		 32 patches of 640x640 (tumor tissue).
# 2023-09-10 20:37:13,195 :: INFO <module> :: 		 257 patches of 640x640 (background).
# 2023-09-10 20:38:08,757 :: INFO <module> :: Processing tma '339.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (103754596 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2023-09-10 20:38:17,215 :: INFO <module> :: 	 256 patches of 640x640 size.
# 2023-09-10 20:38:17,216 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:38:17,217 :: INFO <module> :: 		 27 patches of 640x640 (tumor tissue).
# 2023-09-10 20:38:17,217 :: INFO <module> :: 		 229 patches of 640x640 (background).
# 2023-09-10 20:39:03,435 :: INFO <module> :: Processing tma '340.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (114511401 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2023-09-10 20:39:12,706 :: INFO <module> :: 	 289 patches of 640x640 size.
# 2023-09-10 20:39:12,706 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:39:12,707 :: INFO <module> :: 		 34 patches of 640x640 (tumor tissue).
# 2023-09-10 20:39:12,708 :: INFO <module> :: 		 255 patches of 640x640 (background).
# 2023-09-10 20:40:12,899 :: INFO <module> :: Processing tma '342.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (125888400 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2023-09-10 20:40:22,893 :: INFO <module> :: 	 324 patches of 640x640 size.
# 2023-09-10 20:40:22,894 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:40:22,894 :: INFO <module> :: 		 33 patches of 640x640 (tumor tissue).
# 2023-09-10 20:40:22,895 :: INFO <module> :: 		 291 patches of 640x640 (background).
# 2023-09-10 20:41:22,453 :: INFO <module> :: Processing tma '343.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (120560400 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2023-09-10 20:41:32,226 :: INFO <module> :: 	 324 patches of 640x640 size.
# 2023-09-10 20:41:32,226 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:41:32,227 :: INFO <module> :: 		 28 patches of 640x640 (tumor tissue).
# 2023-09-10 20:41:32,228 :: INFO <module> :: 		 296 patches of 640x640 (background).
# 2023-09-10 20:42:23,354 :: INFO <module> :: Processing tma '344.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (127238400 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2023-09-10 20:42:33,934 :: INFO <module> :: 	 324 patches of 640x640 size.
# 2023-09-10 20:42:33,935 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:42:33,935 :: INFO <module> :: 		 32 patches of 640x640 (tumor tissue).
# 2023-09-10 20:42:33,936 :: INFO <module> :: 		 292 patches of 640x640 (background).
# 2023-09-10 20:43:39,312 :: INFO <module> :: Processing tma '345.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (141134400 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2023-09-10 20:43:51,036 :: INFO <module> :: 	 361 patches of 640x640 size.
# 2023-09-10 20:43:51,037 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:43:51,037 :: INFO <module> :: 		 27 patches of 640x640 (tumor tissue).
# 2023-09-10 20:43:51,038 :: INFO <module> :: 		 334 patches of 640x640 (background).
# 2023-09-10 20:44:51,239 :: INFO <module> :: Processing tma '346.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (124992400 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2023-09-10 20:45:01,361 :: INFO <module> :: 	 324 patches of 640x640 size.
# 2023-09-10 20:45:01,361 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:45:01,362 :: INFO <module> :: 		 32 patches of 640x640 (tumor tissue).
# 2023-09-10 20:45:01,363 :: INFO <module> :: 		 292 patches of 640x640 (background).
# 2023-09-10 20:46:00,312 :: INFO <module> :: Processing tma '347.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (128845201 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2023-09-10 20:46:10,782 :: INFO <module> :: 	 324 patches of 640x640 size.
# 2023-09-10 20:46:10,783 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:46:10,783 :: INFO <module> :: 		 29 patches of 640x640 (tumor tissue).
# 2023-09-10 20:46:10,784 :: INFO <module> :: 		 295 patches of 640x640 (background).
# 2023-09-10 20:47:08,334 :: INFO <module> :: Processing tma '348.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (121198081 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2023-09-10 20:47:18,323 :: INFO <module> :: 	 324 patches of 640x640 size.
# 2023-09-10 20:47:18,324 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:47:18,324 :: INFO <module> :: 		 32 patches of 640x640 (tumor tissue).
# 2023-09-10 20:47:18,326 :: INFO <module> :: 		 292 patches of 640x640 (background).
# 2023-09-10 20:48:20,410 :: INFO <module> :: Processing tma '349.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (127125625 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2023-09-10 20:48:30,441 :: INFO <module> :: 	 324 patches of 640x640 size.
# 2023-09-10 20:48:30,442 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:48:30,442 :: INFO <module> :: 		 26 patches of 640x640 (tumor tissue).
# 2023-09-10 20:48:30,443 :: INFO <module> :: 		 298 patches of 640x640 (background).
# 2023-09-10 20:49:17,579 :: INFO <module> :: Processing tma '351.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (152670736 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2023-09-10 20:49:30,137 :: INFO <module> :: 	 400 patches of 640x640 size.
# 2023-09-10 20:49:30,137 :: INFO <module> :: 		 0 patches of 640x640 (normal tissue).
# 2023-09-10 20:49:30,138 :: INFO <module> :: 		 40 patches of 640x640 (tumor tissue).
# 2023-09-10 20:49:30,139 :: INFO <module> :: 		 360 patches of 640x640 (background).

# %% [markdown]
# # Generate the 512x512 dataset

# %%
from bones_dataloader import *

magnification=0.625
scale = get_scale_by_magnification(magnification)
tile_size=20
tile_size_original = int(scale * tile_size)


cls = "tumor"
dataset_types = ["training", "testing"]
for dataset_type in sorted(dataset_types):
    
    logger.info("{} images".format(dataset_type))
    
    orca_dir = "../../datasets/ORCA"
    annotations_dir = "{}/{}/lesion_annotations".format(orca_dir, dataset_type)
    tma_images_dir = "{}/{}/{}/wsi".format(orca_dir, dataset_type, cls)
    
    orca_512x512_dir = "../../datasets/ORCA_512x512"
    resized_annotations_dir = "{}/{}/lesion_annotations".format(orca_512x512_dir, dataset_type)
    resized_tma_images_dir = "{}/{}/{}/tma".format(orca_512x512_dir, dataset_type, cls)
    
    for r, d, f in sorted(os.walk(tma_images_dir)):
        for tma_file in sorted(f):
            
            tma_image_file = "{}/{}".format(r, tma_file)
            tma_image_number = tma_file.replace(".png", "")
            
            file_is_png = tma_image_file.lower().endswith('.png')
            if file_is_png:

                logger.info("Processing tma '{}'".format(tma_file))
                
                # tumor annotations mask
                annotation_file = "{}/{}.png".format(annotations_dir, tma_image_number)
                tma_mask_pil = load_pil_image(annotation_file, gray=True)
                
                # tumor tma image
                tma_image_pil = load_pil_image(tma_image_file, gray=False)
                
                #print("{}/{}_mask.png".format(resized_annotations_dir, tma_image_number))
                resized_tma_mask_np = image_resize(pil_to_np(tma_mask_pil), width=512, height=512)
                np_tumor_mask = np.zeros((512, 512), dtype=bool)
                np_tumor_mask[resized_tma_mask_np == 255] = True
                pil_tumor_mask = np_to_pil(np_tumor_mask)
                pil_tumor_mask.save("{}/{}.png".format(resized_annotations_dir, tma_image_number))
                
                #print("{}/{}".format(resized_tma_images_dir, tma_file))
                resized_tma_image_np = image_resize(pil_to_np(tma_image_pil), width=512, height=512)
                np_to_pil(resized_tma_image_np).save("{}/{}".format(resized_tma_images_dir, tma_file))
