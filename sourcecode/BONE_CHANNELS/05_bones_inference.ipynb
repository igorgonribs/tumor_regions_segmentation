# %% [markdown]
# # Execute the trained model (WSI level)

# %%
import os
import sys
import matplotlib.pyplot as plt
# %matplotlib inline

import torchvision.transforms.functional as TF
from torchvision import utils
from torch.autograd import Variable

import gc 


current_path = os.path.abspath('.')
root_path = os.path.dirname(os.path.dirname(current_path))
sys.path.append(root_path)

from sourcecode.unet_model import *
from sourcecode.wsi_image_utils import *


torch.cuda.empty_cache()
gc.collect()


dataset_dir = "../../datasets/BONE_CHANNELS"
model_dir = "../../models"

color_model = "LAB"
magnification = 0.625
#magnification = 0.999
scale = get_scale_by_magnification(magnification)
#scale = 1
tile_size = 20
tile_size_original = int(scale * tile_size)
patch_size = (tile_size_original, tile_size_original)

use_cuda=True
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") if use_cuda else "cpu"

# loads our trained fcn model
trained_model_version = "ORCA__Size-640x640_Epoch-100_Images-182_Batch-1__random_distortion"
trained_model_path="{}/{}".format(model_dir, '{}.pth'.format(trained_model_version))

if not os.path.isfile(trained_model_path):
    
    logger.info("Trained model not found: '{}'.".format(trained_model_path))
    
else:

    model = load_checkpoint(file_path=trained_model_path, img_input_size=patch_size, use_cuda=use_cuda)
    
    dataset_type = "testing"
    classes = ["bones"]
    for cls in classes:

        annotations_dir = "{}/{}/annotations".format(dataset_dir, dataset_type)
        wsi_images_dir = "{}/{}/{}/wsi".format(dataset_dir, dataset_type, cls)
        patch_images_dir = "{}/{}/{}/patch/640x640".format(dataset_dir, dataset_type, cls)
        patch_images_results_dir = "{}/results/{}/{}/{}/patch/640x640".format(dataset_dir, trained_model_version, dataset_type, cls)
        wsi_images_results_dir = "{}/results/{}/{}/{}/wsi".format(dataset_dir, trained_model_version, dataset_type, cls)
        print('AAA')
        for r, d, f in sorted(os.walk(wsi_images_dir)):
            print('BBB')
            for wsi_file in sorted(f):
                print('CCC')

                wsi_image_file = "{}/{}".format(r, wsi_file)
                wsi_image_number = wsi_file.replace(".png", "")
                
                file_is_png = wsi_image_file.lower().endswith('.png')
                if file_is_png:
                    print('DDD')

                    logger.info("Processing wsi '{}'".format(wsi_file))
                    if not os.path.isfile(wsi_image_file):
                        logger.info("WSI image not found: '{}'.".format(wsi_file))
                        break
                    
                    # check directory to save image-patches
                    dir_to_save = "{}/{}".format(patch_images_results_dir, wsi_image_number)
                    if not os.path.exists(dir_to_save):
                        os.makedirs("{}/{}".format(wsi_images_results_dir, wsi_image_number))
                        os.makedirs("{}/01-unet_result".format(dir_to_save))
                        
                    # scale down image
                    wsi_image = open_wsi(wsi_image_file)
                    pil_scaled_down_image = scale_down_wsi(wsi_image, magnification, False)
                    np_scaled_down_image = pil_to_np(pil_scaled_down_image)

                    # extract tissue region 
                    np_tissue_mask, np_masked_image = extract_normal_region_from_wsi(wsi_image_file, np_scaled_down_image, None)
                    pil_masked_image = np_to_pil(np_masked_image)
                    max_w = np_masked_image.shape[0]
                    max_h = np_masked_image.shape[1]
                    
                    # draw the heat grid
                    pil_img_result, heat_grid, number_of_tiles = draw_heat_grid(np_masked_image, tile_size)

                    # save scaled down wsi
                    utils.save_image(TF.to_tensor(pil_scaled_down_image), '{}/{}/{}.png'.format(wsi_images_results_dir, wsi_image_number, wsi_image_number))
                    utils.save_image(TF.to_tensor(pil_masked_image), '{}/{}/{}__tissue.png'.format(wsi_images_results_dir, wsi_image_number, wsi_image_number))
                    utils.save_image(TF.to_tensor(pil_img_result), '{}/{}/{}__tissuegrid.png'.format(wsi_images_results_dir, wsi_image_number, wsi_image_number))
                    
                    
                    # run the model
                    count_tiles = 0
                    count_roi_tiles = 0
                    for idx, (position, row, column, location, size, color) in enumerate(heat_grid):

                        if color != GREEN_COLOR:

                            count_tiles += 1

                            #r_s = row * tile_size
                            #r_e = r_s + tile_size
                            #c_s = column * tile_size
                            #c_e = c_s + tile_size                            
                            
                            r_s = row * tile_size
                            r_e = r_s + (tile_size if (r_s + tile_size) <= max_w else (max_w - r_s))
                            c_s = column * tile_size
                            c_e = c_s + (tile_size if (c_s + tile_size) <= max_h else (max_h - c_s))
                            np_tile_masked = np_masked_image[r_s:r_e, c_s:c_e]

                            # only tile with valid size
                            #if np_tile_masked.shape[0] == tile_size and np_tile_masked.shape[1] == tile_size:

                            # read the tile from the original wsi image
                            pil_input_tile, np_input_tile = read_region(wsi_image_file, column, row, magnification, tile_size)

                            # run the model
                            if color_model == "LAB":
                                np_input_tile = rgb_to_lab(np_input_tile)

                            X = torch.from_numpy(np_input_tile).permute(2, 0, 1).float()
                            X = Variable(X.unsqueeze(0)).to(device) if use_cuda else X.unsqueeze(0)
                            y_hat = model(X).detach().cpu().squeeze(0)
                            #y_hat = model(X).squeeze(0)
                            output_tile = y_hat[0]
                            np_output_tile = output_tile.squeeze(0).detach().cpu().numpy()
                            #

                            # only tiles that something was found by model
                            if np.any(np.unique(np_output_tile >= 0.1)):

                                # save the output image-patch results
                                utils.save_image(output_tile, '{}/01-unet_result/{}_r{}c{}.png'.format(dir_to_save, wsi_image_number, row, column))

                                np_output_tile[np_output_tile > 0] = 1
                                count_roi_tiles += 1

                    logger.info("\t '{}/{}/{}' tiles identified as ROI by model".format(count_roi_tiles, count_tiles, len(heat_grid)))
                    logger.info("-")
# Out:
# 2023-11-12 12:08:39,743 :: INFO load_checkpoint :: 	 Model loaded on: cuda / 3 / 1 / (640, 640) / 31734913 params -> ../../models/ORCA__Size-640x640_Epoch-100_Images-182_Batch-1__random_distortion.pth
# 2023-11-12 12:08:39,745 :: INFO <module> :: Processing wsi '202.png'
# AAA
# BBB
# CCC
# DDD
# 2023-11-12 12:08:41,339 :: INFO extract_normal_region_from_wsi :: 	 Extracting normal regions from wsi image: '202.png'
# 2023-11-12 12:11:45,650 :: INFO <module> :: 	 '127/127/169' tiles identified as ROI by model
# 2023-11-12 12:11:45,651 :: INFO <module> :: -
# 2023-11-12 12:11:45,652 :: INFO <module> :: Processing wsi '203.png'
# CCC
# DDD
# 2023-11-12 12:11:47,223 :: INFO extract_normal_region_from_wsi :: 	 Extracting normal regions from wsi image: '203.png'
# 2023-11-12 12:14:42,769 :: INFO <module> :: 	 '125/125/169' tiles identified as ROI by model
# 2023-11-12 12:14:42,770 :: INFO <module> :: -
# 2023-11-12 12:14:42,771 :: INFO <module> :: Processing wsi '204.png'
# CCC
# DDD
# 2023-11-12 12:14:44,488 :: INFO extract_normal_region_from_wsi :: 	 Extracting normal regions from wsi image: '204.png'
# 2023-11-12 12:18:15,010 :: INFO <module> :: 	 '133/133/169' tiles identified as ROI by model
# 2023-11-12 12:18:15,011 :: INFO <module> :: -
# 2023-11-12 12:18:15,011 :: INFO <module> :: Processing wsi '301.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (114490000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# CCC
# DDD
# 2023-11-12 12:18:17,221 :: INFO extract_normal_region_from_wsi :: 	 Extracting normal regions from wsi image: '301.png'
# 2023-11-12 12:21:30,061 :: INFO <module> :: 	 '107/107/289' tiles identified as ROI by model
# 2023-11-12 12:21:30,062 :: INFO <module> :: -
# 2023-11-12 12:21:30,062 :: INFO <module> :: Processing wsi '302.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (105431824 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# CCC
# DDD
# 2023-11-12 12:21:32,273 :: INFO extract_normal_region_from_wsi :: 	 Extracting normal regions from wsi image: '302.png'
# 2023-11-12 12:24:53,503 :: INFO <module> :: 	 '104/104/256' tiles identified as ROI by model
# 2023-11-12 12:24:53,504 :: INFO <module> :: -
# 2023-11-12 12:24:53,505 :: INFO <module> :: Processing wsi '303.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (111028369 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# CCC
# DDD
# 2023-11-12 12:24:55,855 :: INFO extract_normal_region_from_wsi :: 	 Extracting normal regions from wsi image: '303.png'
# 2023-11-12 12:28:43,684 :: INFO <module> :: 	 '109/109/289' tiles identified as ROI by model
# 2023-11-12 12:28:43,686 :: INFO <module> :: -
# 2023-11-12 12:28:43,686 :: INFO <module> :: Processing wsi '304.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (128097124 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# CCC
# DDD
# 2023-11-12 12:28:46,171 :: INFO extract_normal_region_from_wsi :: 	 Extracting normal regions from wsi image: '304.png'
# 2023-11-12 12:32:20,649 :: INFO <module> :: 	 '104/104/324' tiles identified as ROI by model
# 2023-11-12 12:32:20,649 :: INFO <module> :: -
# 2023-11-12 12:32:20,650 :: INFO <module> :: Processing wsi '305.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (137381841 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# CCC
# DDD
# 2023-11-12 12:32:23,299 :: INFO extract_normal_region_from_wsi :: 	 Extracting normal regions from wsi image: '305.png'
# 2023-11-12 12:36:23,515 :: INFO <module> :: 	 '107/107/361' tiles identified as ROI by model
# 2023-11-12 12:36:23,516 :: INFO <module> :: -
# 2023-11-12 12:36:23,517 :: INFO <module> :: Processing wsi '306.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (117202276 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# CCC
# DDD
# 2023-11-12 12:36:25,882 :: INFO extract_normal_region_from_wsi :: 	 Extracting normal regions from wsi image: '306.png'
# 2023-11-12 12:40:06,527 :: INFO <module> :: 	 '108/108/289' tiles identified as ROI by model
# 2023-11-12 12:40:06,528 :: INFO <module> :: -
# 2023-11-12 12:40:06,529 :: INFO <module> :: Processing wsi '310.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (106502400 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# CCC
# DDD
# 2023-11-12 12:40:08,642 :: INFO extract_normal_region_from_wsi :: 	 Extracting normal regions from wsi image: '310.png'
# 2023-11-12 12:43:11,989 :: INFO <module> :: 	 '105/105/289' tiles identified as ROI by model
# 2023-11-12 12:43:11,990 :: INFO <module> :: -
# 2023-11-12 12:43:11,991 :: INFO <module> :: Processing wsi '311.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (105267600 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# CCC
# DDD
# 2023-11-12 12:43:14,272 :: INFO extract_normal_region_from_wsi :: 	 Extracting normal regions from wsi image: '311.png'
# 2023-11-12 12:46:50,406 :: INFO <module> :: 	 '110/110/256' tiles identified as ROI by model
# 2023-11-12 12:46:50,406 :: INFO <module> :: -
# 2023-11-12 12:46:50,407 :: INFO <module> :: Processing wsi '312.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (111513600 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# CCC
# DDD
# 2023-11-12 12:46:52,814 :: INFO extract_normal_region_from_wsi :: 	 Extracting normal regions from wsi image: '312.png'
# 2023-11-12 12:50:30,040 :: INFO <module> :: 	 '105/105/289' tiles identified as ROI by model
# 2023-11-12 12:50:30,040 :: INFO <module> :: -
# 2023-11-12 12:50:30,041 :: INFO <module> :: Processing wsi '313.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (119946304 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# CCC
# DDD
# 2023-11-12 12:50:32,448 :: INFO extract_normal_region_from_wsi :: 	 Extracting normal regions from wsi image: '313.png'
# 2023-11-12 12:53:56,207 :: INFO <module> :: 	 '105/105/324' tiles identified as ROI by model
# 2023-11-12 12:53:56,208 :: INFO <module> :: -
# 2023-11-12 12:53:56,208 :: INFO <module> :: Processing wsi '314.png'
# c:\Users\Igor\anaconda3\envs\dali\lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (118701025 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# CCC
# DDD
# 2023-11-12 12:53:58,577 :: INFO extract_normal_region_from_wsi :: 	 Extracting normal regions from wsi image: '314.png'
# 2023-11-12 12:57:14,819 :: INFO <module> :: 	 '102/102/289' tiles identified as ROI by model
# 2023-11-12 12:57:14,820 :: INFO <module> :: -

# %% [markdown]
# # Generate the heatmaps (WSI level)

# %%
import os
import sys
current_path = os.path.abspath('.')
root_path = os.path.dirname(os.path.dirname(current_path))
sys.path.append(root_path)
from sourcecode.wsi_image_utils import *

import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import *
# %matplotlib inline

import torchvision.transforms.functional as TF
from torchvision import utils


dataset_dir = "../../datasets/BONE_CHANNELS"
model_dir = "../../models"
trained_model_version = "ORCA__Size-640x640_Epoch-100_Images-182_Batch-1__random_distortion"

color_model = "LAB"
magnification = 0.625
scale = get_scale_by_magnification(magnification)
tile_size = 20
tile_size_original = int(scale * tile_size)
patch_size = (tile_size_original, tile_size_original)


dataset_type = "testing"
classes = ["tumor"]
for cls in classes:

    annotations_dir = "{}/{}/annotations".format(dataset_dir, dataset_type)
    wsi_images_dir = "{}/{}/{}/wsi".format(dataset_dir, dataset_type, cls)
    patch_images_dir = "{}/{}/{}/patch/640x640".format(dataset_dir, dataset_type, cls)
    patch_images_results_dir = "{}/results/{}/{}/{}/patch/640x640".format(dataset_dir, trained_model_version, dataset_type, cls)
    wsi_images_results_dir = "{}/results/{}/{}/{}/wsi".format(dataset_dir, trained_model_version, dataset_type, cls)

    for r, d, f in sorted(os.walk(wsi_images_dir)):
        for wsi_file in sorted(f):

            wsi_image_file = "{}/{}".format(r, wsi_file)
            wsi_image_number = wsi_file.replace(".png", "")

            file_is_png = wsi_image_file.lower().endswith('.png')
            if file_is_png:

                logger.info("Segmenting wsi image: '{}'".format(wsi_file))
                unet_results_dir = "{}/{}/01-unet_result".format(patch_images_results_dir, wsi_image_number)
                if not os.path.exists(unet_results_dir):
                    logger.info("\t This WSI image was not processed by our fcn based method yet.")
                    logger.info("\t {}".format(unet_results_dir))
                    continue
                
                original_img_path = "{}/{}/{}.png".format(wsi_images_results_dir, wsi_image_number, wsi_image_number)
                pil_original_image = load_pil_image(original_img_path, gray=False)
                np_scaled_down_image = pil_to_np(pil_original_image)

                # fcn roi identification
                count_tiles = 0
                np_heatmap = np.zeros((np_scaled_down_image.shape[0], np_scaled_down_image.shape[1]))
                np_tissue_roi = np.zeros_like(np_scaled_down_image)
                for _, _, unet_tile_files in sorted(os.walk(unet_results_dir)):
                    for unet_tile_image_file in sorted(unet_tile_files):
                        if os.path.isfile("{}/{}".format(unet_results_dir, unet_tile_image_file)):

                            # load the unet image-patch result
                            np_tile_unet = np.copy(pil_to_np(load_pil_image("{}/{}".format(unet_results_dir, unet_tile_image_file), gray=True)))
                            np_tile_unet = np_tile_unet * (1.0/255)
                            np_tile_unet[np.isnan(np_tile_unet)] = 0

                            # check if exists values greather than 0.x
                            if np.any(np.unique(np_tile_unet > 0.1)):

                                aux_row_column = unet_tile_image_file.split("_")[-1].replace(".png", "").split('c')
                                row = int(aux_row_column[0].replace("r", ""))
                                column = int(aux_row_column[-1])

                                r_s = row * tile_size
                                r_e = r_s + tile_size
                                c_s = column * tile_size
                                c_e = c_s + tile_size
                                np_heatmap[r_s:r_e, c_s:c_e] = image_resize(np_tile_unet, height=tile_size)

                                np_tile_unet = basic_threshold(np_tile_unet, threshold=0.01, output_type="uint8")
                                tissue_area = tissue_percent(np_tile_unet)
                                if tissue_area > 1:

                                    count_tiles += 1

                                else:
                                    np_heatmap[r_s:r_e, c_s:c_e] = 0

                logger.info("\t '{}' tiles identified as ROI after post processing".format(count_tiles))
                logger.info("-")
                
                f = plt.figure(figsize=((np_heatmap.shape[1]*20)/np_heatmap.shape[0], 20))
                f.suptitle("{} Heatmap".format(trained_model_version.split("_")[0]), fontsize=26)

                ax1 = f.add_subplot(111)
                sns.heatmap(np_heatmap, ax=ax1, xticklabels=False, yticklabels=False, vmin=0, vmax=1, cmap="jet", cbar=True, robust=True)

                f.savefig(original_img_path.replace("{}.png".format(wsi_image_number), "{}_heatmap.png".format(wsi_image_number)))
                utils.save_image(TF.to_tensor(np_to_pil(np_heatmap)), original_img_path.replace("{}.png".format(wsi_image_number), "{}_heatmap_gray.png".format(wsi_image_number)))

# %% [markdown]
# # Generate the lesion localization points (WSI level)

# %%
import os
import sys
current_path = os.path.abspath('.')
root_path = os.path.dirname(os.path.dirname(current_path))
sys.path.append(root_path)
from sourcecode.wsi_image_utils import *

import csv
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import *
# %matplotlib inline

import torchvision.transforms.functional as TF
from torchvision import utils

from scipy import ndimage as nd
from skimage import measure

dataset_dir = "../../datasets/BONE_CHANNELS"
model_dir = "../../models"
trained_model_version = "ORCA__Size-640x640_Epoch-100_Images-182_Batch-1__random_distortion"

color_model = "LAB"
magnification = 0.625
scale = get_scale_by_magnification(magnification)
tile_size = 20
tile_size_original = int(scale * tile_size)
patch_size = (tile_size_original, tile_size_original)

threshold_prob = 0.5
threshold_itc = 200/(0.243 * pow(2, 5))

dataset_type = "testing"
classes = ["bones"]
for cls in classes:

    wsi_images_dir = "{}/{}/{}/wsi".format(dataset_dir, dataset_type, cls)
    wsi_images_results_dir = "{}/results/{}/{}/{}/wsi".format(dataset_dir, trained_model_version, dataset_type, cls)

    for r, d, f in sorted(os.walk(wsi_images_dir)):
        for wsi_file in sorted(f):

            wsi_image_file = "{}/{}".format(r, wsi_file)
            wsi_image_number = wsi_file.replace(".png", "")

            file_is_png = wsi_image_file.lower().endswith('.png')
            if file_is_png:
                
                logger.info("Generating the lesion localization points for wsi image: '{}'".format(wsi_file))
                
                heatmap_gray_path = "{}/{}/{}_heatmap_gray.png".format(wsi_images_results_dir, wsi_image_number, wsi_image_number)
                if not os.path.exists(heatmap_gray_path):
                    logger.info("\t This original WSI image was not processed yet.")
                    logger.info("\t {}".format(heatmap_gray_path))
                    continue
                                
                np_heatmap_gray = load_np_image(heatmap_gray_path, color_model="GRAY") * (1.0/255)
                np_heatmap_points = np.zeros((np_heatmap_gray.shape[0], np_heatmap_gray.shape[1]))
                np_heatmap_convex = np.zeros((np_heatmap_gray.shape[0], np_heatmap_gray.shape[1]))

                seg_threshold_img = basic_threshold(np_heatmap_gray, threshold=threshold_prob, output_type="uint8")
                seg_threshold_img = nd.morphology.binary_fill_holes(seg_threshold_img)
                
                seg_threshold_img_labels = measure.label(seg_threshold_img, connectivity=2)
                seg_threshold_img = np.zeros((np_heatmap_gray.shape[0], np_heatmap_gray.shape[1]))
                
                properties = measure.regionprops(seg_threshold_img_labels)
                
                csv_file_path = heatmap_gray_path.replace("_heatmap_gray.png", ".csv")
                with open(csv_file_path, mode='w') as result_file:

                    result_writer = csv.writer(result_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                                        
                    labels = np.unique(seg_threshold_img_labels)
                    for lbl in range(1, (np.max(labels)+1)):
                        
                        centroid = (int(properties[lbl-1].centroid[0]), int(properties[lbl-1].centroid[1]))
                        major_axis_length = properties[lbl-1].major_axis_length
                        
                        if major_axis_length > threshold_itc:

                            hull = properties[lbl-1].convex_image
                            bbox = properties[lbl-1].bbox
                            #mean_intensity = np.mean(np_heatmap_gray[bbox[0]:bbox[2], bbox[1]:bbox[3]][hull==True])
                            #centroid_intensity = np_heatmap_gray[centroid[0], centroid[1]]
                            max_intensity = np.max(np_heatmap_gray[bbox[0]:bbox[2], bbox[1]:bbox[3]][hull==True])
                                                        
                            prob = max_intensity
                            if prob > 0.0:
                                
                                #print("   {:04.2f}, {}, {}".format(prob, centroid[1], centroid[0]))
                                seg_threshold_img[seg_threshold_img_labels == lbl] = 1
                                
                                result_writer.writerow(["{:04.2f}".format(prob), centroid[1], centroid[0]])
                                np_heatmap_points[centroid[0]-10:centroid[0]+10, centroid[1]-10:centroid[1]+10] = 1
                                np_heatmap_convex[bbox[0]:bbox[2], bbox[1]:bbox[3]][hull==True] = 1
                                np_heatmap_convex[centroid[0]-10:centroid[0]+10, centroid[1]-10:centroid[1]+10] = 0.5
                        
                utils.save_image(TF.to_tensor(np_to_pil(seg_threshold_img)), heatmap_gray_path.replace("_gray", "_gray_threshold_{}".format(threshold_prob)))
                utils.save_image(TF.to_tensor(np_to_pil(np_heatmap_points)), heatmap_gray_path.replace("_gray", "_points"))
                #utils.save_image(TF.to_tensor(np_to_pil(np_heatmap_convex)), heatmap_gray_path.replace("_gray", "_gray_threshold_{}_convex".format(threshold_prob)))

# %% [markdown]
# # Execute the trained model (image-patch level)

# %%
from sourcecode.BONE_CHANNELS.bones_train import *
from sourcecode.BONE_CHANNELS.bones_dataloader import *

import torchvision.transforms.functional as TF
from torchvision import transforms
from torchvision import utils
from datetime import datetime

from scipy import ndimage as nd
from skimage import measure

dataset_dir = "../../datasets/BONE_CHANNELS"
model_dir = "../../models"

batch_size = 1
patch_size = (640, 640)
color_model = "LAB"
dataloaders = create_dataloader(tile_size="{}x{}".format(patch_size[0], patch_size[1]),
                                batch_size=batch_size, 
                                shuffle=False,
                                img_input_size=patch_size,
                                img_output_size=patch_size,
                                dataset_dir=dataset_dir,
                                color_model=color_model)

dataset_train_size = len(dataloaders['train'].dataset)
dataset_test_size = len(dataloaders['test'].dataset)


threshold_prob = 0.10
threshold_itc = 200/(0.243 * pow(2, 5))


# Checking for GPU availability
use_cuda=True
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") if use_cuda else "cpu"
logger.info('Runing on: {}'.format(device))

# loads our trained fcn model
trained_model_version = "ORCA__Size-640x640_Epoch-100_Images-182_Batch-1__random_distortion"
trained_model_path="{}/{}".format(model_dir, '{}.pth'.format(trained_model_version))
model = load_checkpoint(file_path=trained_model_path, img_input_size=patch_size, use_cuda=use_cuda)
cont = 0
for batch_idx, (images, masks, fname, original_size) in enumerate(dataloaders['test']):
        
    X = Variable(images).to(device) if use_cuda else images
    logger.info('Batch {}: {}/{} images: {} masks: {} {}'.format(
                (batch_idx+1), 
                (batch_idx+1) * len(images), 
                len(dataloaders['test'].dataset),
                images.shape,
                masks.shape,
                datetime.now().strftime('%d/%m/%Y %H:%M:%S')))
    
    #X_numpy = X.cpu().numpy()
    y_hat = model(X).detach().cpu().squeeze(0)
    cls = "bones"
    
    input_image = transforms.ToPILImage()(X.squeeze(0).cpu())
    output_mask = basic_threshold(y_hat[0].detach().cpu().numpy(), threshold=threshold_prob, output_type="uint8")

    predicted_labels = measure.label(output_mask, connectivity=2)
    output_mask = np.zeros((output_mask.shape[0], output_mask.shape[1]))
    labels = np.unique(predicted_labels)
    properties = measure.regionprops(predicted_labels)
    for lbl in range(1, (np.max(labels)+1)):
        major_axis_length = properties[lbl-1].major_axis_length
        if major_axis_length > threshold_itc:
            output_mask[predicted_labels == lbl] = 1

    input_image_rgb = lab_to_rgb(pil_to_np(input_image))
    roi_image = blend_image(np_to_pil(input_image_rgb), np_to_pil(output_mask), foreground='red', alpha=0.6, inverse=True)

    # results dir
    wsi_image_number = fname[0].split("_")[0] + "_" + fname[0].split("_")[1]
    patch_images_results_dir = "{}/results/{}/testing/{}/patch/640x640/{}".format(dataset_dir, trained_model_version, cls, wsi_image_number)
    results_output_dir = "{}/01-unet_result".format(patch_images_results_dir)
    if not os.path.exists(results_output_dir):
        os.makedirs(results_output_dir)
        
    results_roi_dir = "{}/02-roi".format(patch_images_results_dir)
    if not os.path.exists(results_roi_dir):
        os.makedirs(results_roi_dir)

    # save the results
    patch_img_name = fname[0]
    utils.save_image(y_hat[0], '{}/{}'.format(results_output_dir, patch_img_name))
    utils.save_image(TF.to_tensor(roi_image), '{}/{}'.format(results_roi_dir, patch_img_name))
# Out:
# 2023-09-12 09:36:59,891 :: INFO load_dataset :: [training] ../../datasets/BONE_CHANNELS/training
# 2023-09-12 09:36:59,958 :: INFO load_dataset :: [training] ../../datasets/BONE_CHANNELS/training
# 2023-09-12 09:37:00,023 :: INFO load_dataset :: [testing] ../../datasets/BONE_CHANNELS/testing
# 2023-09-12 09:37:00,044 :: INFO create_dataloader :: Train images (640x640): 1573 augmentation: random
# 2023-09-12 09:37:00,044 :: INFO create_dataloader :: Test images (640x640): 464 augmentation: no_augmentation
# 2023-09-12 09:37:00,046 :: INFO <module> :: Runing on: cuda
# 2023-09-12 09:37:00,680 :: INFO load_checkpoint :: 	 Model loaded on: cuda / 3 / 1 / (640, 640) / 31734913 params -> ../../models/ORCA__Size-640x640_Epoch-100_Images-182_Batch-1__random_distortion.pth
# 2023-09-12 09:37:00,821 :: INFO transform :: Epoch: '1' augmentation no_augmentation None
# 2023-09-12 09:37:00,839 :: INFO <module> :: Batch 1: 1/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:00
# 2023-09-12 09:37:01,643 :: INFO <module> :: Batch 2: 2/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:01
# 2023-09-12 09:37:02,136 :: INFO <module> :: Batch 3: 3/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:02
# 2023-09-12 09:37:02,628 :: INFO <module> :: Batch 4: 4/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:02
# 2023-09-12 09:37:03,121 :: INFO <module> :: Batch 5: 5/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:03
# 2023-09-12 09:37:03,632 :: INFO <module> :: Batch 6: 6/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:03
# 2023-09-12 09:37:04,120 :: INFO <module> :: Batch 7: 7/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:04
# 2023-09-12 09:37:04,621 :: INFO <module> :: Batch 8: 8/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:04
# 2023-09-12 09:37:05,116 :: INFO <module> :: Batch 9: 9/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:05
# 2023-09-12 09:37:05,608 :: INFO <module> :: Batch 10: 10/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:05
# 2023-09-12 09:37:06,061 :: INFO <module> :: Batch 11: 11/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:06
# 2023-09-12 09:37:06,556 :: INFO <module> :: Batch 12: 12/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:06
# 2023-09-12 09:37:07,024 :: INFO <module> :: Batch 13: 13/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:07
# 2023-09-12 09:37:07,511 :: INFO <module> :: Batch 14: 14/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:07
# 2023-09-12 09:37:08,007 :: INFO <module> :: Batch 15: 15/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:08
# 2023-09-12 09:37:08,509 :: INFO <module> :: Batch 16: 16/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:08
# 2023-09-12 09:37:08,989 :: INFO <module> :: Batch 17: 17/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:08
# 2023-09-12 09:37:09,484 :: INFO <module> :: Batch 18: 18/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:09
# 2023-09-12 09:37:09,974 :: INFO <module> :: Batch 19: 19/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:09
# 2023-09-12 09:37:10,440 :: INFO <module> :: Batch 20: 20/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:10
# 2023-09-12 09:37:10,943 :: INFO <module> :: Batch 21: 21/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:10
# 2023-09-12 09:37:11,432 :: INFO <module> :: Batch 22: 22/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:11
# 2023-09-12 09:37:11,863 :: INFO <module> :: Batch 23: 23/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:11
# 2023-09-12 09:37:12,343 :: INFO <module> :: Batch 24: 24/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:12
# 2023-09-12 09:37:12,841 :: INFO <module> :: Batch 25: 25/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:12
# 2023-09-12 09:37:13,345 :: INFO <module> :: Batch 26: 26/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:13
# 2023-09-12 09:37:13,837 :: INFO <module> :: Batch 27: 27/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:13
# 2023-09-12 09:37:14,311 :: INFO <module> :: Batch 28: 28/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:14
# 2023-09-12 09:37:14,742 :: INFO <module> :: Batch 29: 29/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:14
# 2023-09-12 09:37:15,224 :: INFO <module> :: Batch 30: 30/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:15
# 2023-09-12 09:37:15,717 :: INFO <module> :: Batch 31: 31/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:15
# 2023-09-12 09:37:16,206 :: INFO <module> :: Batch 32: 32/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:16
# 2023-09-12 09:37:16,696 :: INFO <module> :: Batch 33: 33/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:16
# 2023-09-12 09:37:17,188 :: INFO <module> :: Batch 34: 34/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:17
# 2023-09-12 09:37:17,645 :: INFO <module> :: Batch 35: 35/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:17
# 2023-09-12 09:37:18,125 :: INFO <module> :: Batch 36: 36/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:18
# 2023-09-12 09:37:18,616 :: INFO <module> :: Batch 37: 37/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:18
# 2023-09-12 09:37:19,059 :: INFO <module> :: Batch 38: 38/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:19
# 2023-09-12 09:37:19,538 :: INFO <module> :: Batch 39: 39/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:19
# 2023-09-12 09:37:20,030 :: INFO <module> :: Batch 40: 40/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:20
# 2023-09-12 09:37:20,473 :: INFO <module> :: Batch 41: 41/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:20
# 2023-09-12 09:37:20,948 :: INFO <module> :: Batch 42: 42/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:20
# 2023-09-12 09:37:21,445 :: INFO <module> :: Batch 43: 43/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:21
# 2023-09-12 09:37:21,939 :: INFO <module> :: Batch 44: 44/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:21
# 2023-09-12 09:37:22,434 :: INFO <module> :: Batch 45: 45/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:22
# 2023-09-12 09:37:22,897 :: INFO <module> :: Batch 46: 46/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:22
# 2023-09-12 09:37:23,385 :: INFO <module> :: Batch 47: 47/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:23
# 2023-09-12 09:37:23,877 :: INFO <module> :: Batch 48: 48/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:23
# 2023-09-12 09:37:24,368 :: INFO <module> :: Batch 49: 49/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:24
# 2023-09-12 09:37:24,861 :: INFO <module> :: Batch 50: 50/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:24
# 2023-09-12 09:37:25,367 :: INFO <module> :: Batch 51: 51/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:25
# 2023-09-12 09:37:25,860 :: INFO <module> :: Batch 52: 52/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:25
# 2023-09-12 09:37:26,293 :: INFO <module> :: Batch 53: 53/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:26
# 2023-09-12 09:37:26,782 :: INFO <module> :: Batch 54: 54/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:26
# 2023-09-12 09:37:27,272 :: INFO <module> :: Batch 55: 55/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:27
# 2023-09-12 09:37:27,761 :: INFO <module> :: Batch 56: 56/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:27
# 2023-09-12 09:37:28,254 :: INFO <module> :: Batch 57: 57/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:28
# 2023-09-12 09:37:28,741 :: INFO <module> :: Batch 58: 58/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:28
# 2023-09-12 09:37:29,202 :: INFO <module> :: Batch 59: 59/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:29
# 2023-09-12 09:37:29,666 :: INFO <module> :: Batch 60: 60/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:29
# 2023-09-12 09:37:30,139 :: INFO <module> :: Batch 61: 61/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:30
# 2023-09-12 09:37:30,622 :: INFO <module> :: Batch 62: 62/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:30
# 2023-09-12 09:37:31,116 :: INFO <module> :: Batch 63: 63/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:31
# 2023-09-12 09:37:31,603 :: INFO <module> :: Batch 64: 64/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:31
# 2023-09-12 09:37:32,077 :: INFO <module> :: Batch 65: 65/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:32
# 2023-09-12 09:37:32,509 :: INFO <module> :: Batch 66: 66/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:32
# 2023-09-12 09:37:33,001 :: INFO <module> :: Batch 67: 67/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:33
# 2023-09-12 09:37:33,473 :: INFO <module> :: Batch 68: 68/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:33
# 2023-09-12 09:37:33,947 :: INFO <module> :: Batch 69: 69/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:33
# 2023-09-12 09:37:34,415 :: INFO <module> :: Batch 70: 70/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:34
# 2023-09-12 09:37:34,908 :: INFO <module> :: Batch 71: 71/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:34
# 2023-09-12 09:37:35,382 :: INFO <module> :: Batch 72: 72/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:35
# 2023-09-12 09:37:35,870 :: INFO <module> :: Batch 73: 73/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:35
# 2023-09-12 09:37:36,349 :: INFO <module> :: Batch 74: 74/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:36
# 2023-09-12 09:37:36,806 :: INFO <module> :: Batch 75: 75/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:36
# 2023-09-12 09:37:37,278 :: INFO <module> :: Batch 76: 76/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:37
# 2023-09-12 09:37:37,765 :: INFO <module> :: Batch 77: 77/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:37
# 2023-09-12 09:37:38,228 :: INFO <module> :: Batch 78: 78/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:38
# 2023-09-12 09:37:38,713 :: INFO <module> :: Batch 79: 79/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:38
# 2023-09-12 09:37:39,189 :: INFO <module> :: Batch 80: 80/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:39
# 2023-09-12 09:37:39,674 :: INFO <module> :: Batch 81: 81/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:39
# 2023-09-12 09:37:40,151 :: INFO <module> :: Batch 82: 82/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:40
# 2023-09-12 09:37:40,614 :: INFO <module> :: Batch 83: 83/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:40
# 2023-09-12 09:37:41,099 :: INFO <module> :: Batch 84: 84/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:41
# 2023-09-12 09:37:41,580 :: INFO <module> :: Batch 85: 85/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:41
# 2023-09-12 09:37:42,071 :: INFO <module> :: Batch 86: 86/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:42
# 2023-09-12 09:37:42,546 :: INFO <module> :: Batch 87: 87/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:42
# 2023-09-12 09:37:43,027 :: INFO <module> :: Batch 88: 88/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:43
# 2023-09-12 09:37:43,479 :: INFO <module> :: Batch 89: 89/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:43
# 2023-09-12 09:37:43,931 :: INFO <module> :: Batch 90: 90/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:43
# 2023-09-12 09:37:44,345 :: INFO <module> :: Batch 91: 91/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:44
# 2023-09-12 09:37:44,824 :: INFO <module> :: Batch 92: 92/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:44
# 2023-09-12 09:37:45,304 :: INFO <module> :: Batch 93: 93/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:45
# 2023-09-12 09:37:45,746 :: INFO <module> :: Batch 94: 94/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:45
# 2023-09-12 09:37:46,220 :: INFO <module> :: Batch 95: 95/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:46
# 2023-09-12 09:37:46,693 :: INFO <module> :: Batch 96: 96/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:46
# 2023-09-12 09:37:47,166 :: INFO <module> :: Batch 97: 97/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:47
# 2023-09-12 09:37:47,607 :: INFO <module> :: Batch 98: 98/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:47
# 2023-09-12 09:37:48,087 :: INFO <module> :: Batch 99: 99/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:48
# 2023-09-12 09:37:48,572 :: INFO <module> :: Batch 100: 100/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:48
# 2023-09-12 09:37:49,022 :: INFO <module> :: Batch 101: 101/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:49
# 2023-09-12 09:37:49,508 :: INFO <module> :: Batch 102: 102/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:49
# 2023-09-12 09:37:49,998 :: INFO <module> :: Batch 103: 103/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:49
# 2023-09-12 09:37:50,474 :: INFO <module> :: Batch 104: 104/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:50
# 2023-09-12 09:37:50,955 :: INFO <module> :: Batch 105: 105/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:50
# 2023-09-12 09:37:51,353 :: INFO <module> :: Batch 106: 106/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:51
# 2023-09-12 09:37:51,842 :: INFO <module> :: Batch 107: 107/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:51
# 2023-09-12 09:37:52,308 :: INFO <module> :: Batch 108: 108/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:52
# 2023-09-12 09:37:52,800 :: INFO <module> :: Batch 109: 109/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:52
# 2023-09-12 09:37:53,286 :: INFO <module> :: Batch 110: 110/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:53
# 2023-09-12 09:37:53,772 :: INFO <module> :: Batch 111: 111/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:53
# 2023-09-12 09:37:54,252 :: INFO <module> :: Batch 112: 112/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:54
# 2023-09-12 09:37:54,688 :: INFO <module> :: Batch 113: 113/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:54
# 2023-09-12 09:37:55,176 :: INFO <module> :: Batch 114: 114/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:55
# 2023-09-12 09:37:55,652 :: INFO <module> :: Batch 115: 115/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:55
# 2023-09-12 09:37:56,114 :: INFO <module> :: Batch 116: 116/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:56
# 2023-09-12 09:37:56,601 :: INFO <module> :: Batch 117: 117/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:56
# 2023-09-12 09:37:57,074 :: INFO <module> :: Batch 118: 118/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:57
# 2023-09-12 09:37:57,567 :: INFO <module> :: Batch 119: 119/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:57
# 2023-09-12 09:37:58,048 :: INFO <module> :: Batch 120: 120/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:58
# 2023-09-12 09:37:58,497 :: INFO <module> :: Batch 121: 121/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:58
# 2023-09-12 09:37:58,963 :: INFO <module> :: Batch 122: 122/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:58
# 2023-09-12 09:37:59,438 :: INFO <module> :: Batch 123: 123/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:59
# 2023-09-12 09:37:59,892 :: INFO <module> :: Batch 124: 124/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:37:59
# 2023-09-12 09:38:00,367 :: INFO <module> :: Batch 125: 125/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:00
# 2023-09-12 09:38:00,828 :: INFO <module> :: Batch 126: 126/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:00
# 2023-09-12 09:38:01,310 :: INFO <module> :: Batch 127: 127/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:01
# 2023-09-12 09:38:01,748 :: INFO <module> :: Batch 128: 128/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:01
# 2023-09-12 09:38:02,218 :: INFO <module> :: Batch 129: 129/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:02
# 2023-09-12 09:38:02,684 :: INFO <module> :: Batch 130: 130/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:02
# 2023-09-12 09:38:03,167 :: INFO <module> :: Batch 131: 131/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:03
# 2023-09-12 09:38:03,632 :: INFO <module> :: Batch 132: 132/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:03
# 2023-09-12 09:38:04,089 :: INFO <module> :: Batch 133: 133/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:04
# 2023-09-12 09:38:04,574 :: INFO <module> :: Batch 134: 134/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:04
# 2023-09-12 09:38:05,051 :: INFO <module> :: Batch 135: 135/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:05
# 2023-09-12 09:38:05,518 :: INFO <module> :: Batch 136: 136/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:05
# 2023-09-12 09:38:05,964 :: INFO <module> :: Batch 137: 137/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:05
# 2023-09-12 09:38:06,417 :: INFO <module> :: Batch 138: 138/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:06
# 2023-09-12 09:38:06,907 :: INFO <module> :: Batch 139: 139/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:06
# 2023-09-12 09:38:07,381 :: INFO <module> :: Batch 140: 140/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:07
# 2023-09-12 09:38:07,871 :: INFO <module> :: Batch 141: 141/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:07
# 2023-09-12 09:38:08,366 :: INFO <module> :: Batch 142: 142/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:08
# 2023-09-12 09:38:08,855 :: INFO <module> :: Batch 143: 143/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:08
# 2023-09-12 09:38:09,323 :: INFO <module> :: Batch 144: 144/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:09
# 2023-09-12 09:38:09,789 :: INFO <module> :: Batch 145: 145/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:09
# 2023-09-12 09:38:10,279 :: INFO <module> :: Batch 146: 146/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:10
# 2023-09-12 09:38:10,736 :: INFO <module> :: Batch 147: 147/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:10
# 2023-09-12 09:38:11,229 :: INFO <module> :: Batch 148: 148/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:11
# 2023-09-12 09:38:11,682 :: INFO <module> :: Batch 149: 149/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:11
# 2023-09-12 09:38:12,178 :: INFO <module> :: Batch 150: 150/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:12
# 2023-09-12 09:38:12,666 :: INFO <module> :: Batch 151: 151/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:12
# 2023-09-12 09:38:13,128 :: INFO <module> :: Batch 152: 152/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:13
# 2023-09-12 09:38:13,617 :: INFO <module> :: Batch 153: 153/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:13
# 2023-09-12 09:38:14,104 :: INFO <module> :: Batch 154: 154/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:14
# 2023-09-12 09:38:14,590 :: INFO <module> :: Batch 155: 155/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:14
# 2023-09-12 09:38:15,031 :: INFO <module> :: Batch 156: 156/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:15
# 2023-09-12 09:38:15,513 :: INFO <module> :: Batch 157: 157/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:15
# 2023-09-12 09:38:15,986 :: INFO <module> :: Batch 158: 158/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:15
# 2023-09-12 09:38:16,465 :: INFO <module> :: Batch 159: 159/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:16
# 2023-09-12 09:38:16,940 :: INFO <module> :: Batch 160: 160/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:16
# 2023-09-12 09:38:17,432 :: INFO <module> :: Batch 161: 161/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:17
# 2023-09-12 09:38:17,886 :: INFO <module> :: Batch 162: 162/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:17
# 2023-09-12 09:38:18,363 :: INFO <module> :: Batch 163: 163/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:18
# 2023-09-12 09:38:18,836 :: INFO <module> :: Batch 164: 164/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:18
# 2023-09-12 09:38:19,295 :: INFO <module> :: Batch 165: 165/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:19
# 2023-09-12 09:38:19,736 :: INFO <module> :: Batch 166: 166/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:19
# 2023-09-12 09:38:20,211 :: INFO <module> :: Batch 167: 167/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:20
# 2023-09-12 09:38:20,679 :: INFO <module> :: Batch 168: 168/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:20
# 2023-09-12 09:38:21,137 :: INFO <module> :: Batch 169: 169/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:21
# 2023-09-12 09:38:21,615 :: INFO <module> :: Batch 170: 170/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:21
# 2023-09-12 09:38:22,090 :: INFO <module> :: Batch 171: 171/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:22
# 2023-09-12 09:38:22,551 :: INFO <module> :: Batch 172: 172/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:22
# 2023-09-12 09:38:23,009 :: INFO <module> :: Batch 173: 173/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:23
# 2023-09-12 09:38:23,483 :: INFO <module> :: Batch 174: 174/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:23
# 2023-09-12 09:38:23,924 :: INFO <module> :: Batch 175: 175/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:23
# 2023-09-12 09:38:24,389 :: INFO <module> :: Batch 176: 176/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:24
# 2023-09-12 09:38:24,855 :: INFO <module> :: Batch 177: 177/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:24
# 2023-09-12 09:38:25,325 :: INFO <module> :: Batch 178: 178/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:25
# 2023-09-12 09:38:25,766 :: INFO <module> :: Batch 179: 179/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:25
# 2023-09-12 09:38:26,220 :: INFO <module> :: Batch 180: 180/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:26
# 2023-09-12 09:38:26,682 :: INFO <module> :: Batch 181: 181/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:26
# 2023-09-12 09:38:27,148 :: INFO <module> :: Batch 182: 182/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:27
# 2023-09-12 09:38:27,624 :: INFO <module> :: Batch 183: 183/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:27
# 2023-09-12 09:38:28,085 :: INFO <module> :: Batch 184: 184/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:28
# 2023-09-12 09:38:28,520 :: INFO <module> :: Batch 185: 185/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:28
# 2023-09-12 09:38:28,969 :: INFO <module> :: Batch 186: 186/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:28
# 2023-09-12 09:38:29,435 :: INFO <module> :: Batch 187: 187/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:29
# 2023-09-12 09:38:29,896 :: INFO <module> :: Batch 188: 188/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:29
# 2023-09-12 09:38:30,369 :: INFO <module> :: Batch 189: 189/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:30
# 2023-09-12 09:38:30,857 :: INFO <module> :: Batch 190: 190/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:30
# 2023-09-12 09:38:31,349 :: INFO <module> :: Batch 191: 191/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:31
# 2023-09-12 09:38:31,835 :: INFO <module> :: Batch 192: 192/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:31
# 2023-09-12 09:38:32,296 :: INFO <module> :: Batch 193: 193/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:32
# 2023-09-12 09:38:32,742 :: INFO <module> :: Batch 194: 194/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:32
# 2023-09-12 09:38:33,172 :: INFO <module> :: Batch 195: 195/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:33
# 2023-09-12 09:38:33,602 :: INFO <module> :: Batch 196: 196/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:33
# 2023-09-12 09:38:34,037 :: INFO <module> :: Batch 197: 197/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:34
# 2023-09-12 09:38:34,515 :: INFO <module> :: Batch 198: 198/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:34
# 2023-09-12 09:38:34,952 :: INFO <module> :: Batch 199: 199/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:34
# 2023-09-12 09:38:35,444 :: INFO <module> :: Batch 200: 200/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:35
# 2023-09-12 09:38:35,909 :: INFO <module> :: Batch 201: 201/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:35
# 2023-09-12 09:38:36,400 :: INFO <module> :: Batch 202: 202/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:36
# 2023-09-12 09:38:36,878 :: INFO <module> :: Batch 203: 203/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:36
# 2023-09-12 09:38:37,359 :: INFO <module> :: Batch 204: 204/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:37
# 2023-09-12 09:38:37,843 :: INFO <module> :: Batch 205: 205/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:37
# 2023-09-12 09:38:38,316 :: INFO <module> :: Batch 206: 206/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:38
# 2023-09-12 09:38:38,794 :: INFO <module> :: Batch 207: 207/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:38
# 2023-09-12 09:38:39,257 :: INFO <module> :: Batch 208: 208/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:39
# 2023-09-12 09:38:39,731 :: INFO <module> :: Batch 209: 209/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:39
# 2023-09-12 09:38:40,204 :: INFO <module> :: Batch 210: 210/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:40
# 2023-09-12 09:38:40,656 :: INFO <module> :: Batch 211: 211/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:40
# 2023-09-12 09:38:41,115 :: INFO <module> :: Batch 212: 212/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:41
# 2023-09-12 09:38:41,564 :: INFO <module> :: Batch 213: 213/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:41
# 2023-09-12 09:38:42,009 :: INFO <module> :: Batch 214: 214/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:42
# 2023-09-12 09:38:42,476 :: INFO <module> :: Batch 215: 215/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:42
# 2023-09-12 09:38:42,941 :: INFO <module> :: Batch 216: 216/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:42
# 2023-09-12 09:38:43,400 :: INFO <module> :: Batch 217: 217/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:43
# 2023-09-12 09:38:43,859 :: INFO <module> :: Batch 218: 218/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:43
# 2023-09-12 09:38:44,313 :: INFO <module> :: Batch 219: 219/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:44
# 2023-09-12 09:38:44,729 :: INFO <module> :: Batch 220: 220/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:44
# 2023-09-12 09:38:45,182 :: INFO <module> :: Batch 221: 221/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:45
# 2023-09-12 09:38:45,644 :: INFO <module> :: Batch 222: 222/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:45
# 2023-09-12 09:38:46,100 :: INFO <module> :: Batch 223: 223/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:46
# 2023-09-12 09:38:46,537 :: INFO <module> :: Batch 224: 224/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:46
# 2023-09-12 09:38:47,008 :: INFO <module> :: Batch 225: 225/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:47
# 2023-09-12 09:38:47,469 :: INFO <module> :: Batch 226: 226/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:47
# 2023-09-12 09:38:47,931 :: INFO <module> :: Batch 227: 227/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:47
# 2023-09-12 09:38:48,397 :: INFO <module> :: Batch 228: 228/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:48
# 2023-09-12 09:38:48,846 :: INFO <module> :: Batch 229: 229/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:48
# 2023-09-12 09:38:49,316 :: INFO <module> :: Batch 230: 230/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:49
# 2023-09-12 09:38:49,798 :: INFO <module> :: Batch 231: 231/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:49
# 2023-09-12 09:38:50,268 :: INFO <module> :: Batch 232: 232/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:50
# 2023-09-12 09:38:50,741 :: INFO <module> :: Batch 233: 233/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:50
# 2023-09-12 09:38:51,189 :: INFO <module> :: Batch 234: 234/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:51
# 2023-09-12 09:38:51,674 :: INFO <module> :: Batch 235: 235/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:51
# 2023-09-12 09:38:52,091 :: INFO <module> :: Batch 236: 236/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:52
# 2023-09-12 09:38:52,551 :: INFO <module> :: Batch 237: 237/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:52
# 2023-09-12 09:38:53,009 :: INFO <module> :: Batch 238: 238/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:53
# 2023-09-12 09:38:53,491 :: INFO <module> :: Batch 239: 239/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:53
# 2023-09-12 09:38:53,943 :: INFO <module> :: Batch 240: 240/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:53
# 2023-09-12 09:38:54,421 :: INFO <module> :: Batch 241: 241/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:54
# 2023-09-12 09:38:54,878 :: INFO <module> :: Batch 242: 242/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:54
# 2023-09-12 09:38:55,353 :: INFO <module> :: Batch 243: 243/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:55
# 2023-09-12 09:38:55,825 :: INFO <module> :: Batch 244: 244/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:55
# 2023-09-12 09:38:56,283 :: INFO <module> :: Batch 245: 245/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:56
# 2023-09-12 09:38:56,750 :: INFO <module> :: Batch 246: 246/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:56
# 2023-09-12 09:38:57,201 :: INFO <module> :: Batch 247: 247/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:57
# 2023-09-12 09:38:57,657 :: INFO <module> :: Batch 248: 248/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:57
# 2023-09-12 09:38:58,117 :: INFO <module> :: Batch 249: 249/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:58
# 2023-09-12 09:38:58,576 :: INFO <module> :: Batch 250: 250/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:58
# 2023-09-12 09:38:59,040 :: INFO <module> :: Batch 251: 251/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:59
# 2023-09-12 09:38:59,486 :: INFO <module> :: Batch 252: 252/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:59
# 2023-09-12 09:38:59,959 :: INFO <module> :: Batch 253: 253/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:38:59
# 2023-09-12 09:39:00,430 :: INFO <module> :: Batch 254: 254/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:00
# 2023-09-12 09:39:00,895 :: INFO <module> :: Batch 255: 255/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:00
# 2023-09-12 09:39:01,358 :: INFO <module> :: Batch 256: 256/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:01
# 2023-09-12 09:39:01,828 :: INFO <module> :: Batch 257: 257/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:01
# 2023-09-12 09:39:02,240 :: INFO <module> :: Batch 258: 258/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:02
# 2023-09-12 09:39:02,735 :: INFO <module> :: Batch 259: 259/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:02
# 2023-09-12 09:39:03,231 :: INFO <module> :: Batch 260: 260/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:03
# 2023-09-12 09:39:03,729 :: INFO <module> :: Batch 261: 261/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:03
# 2023-09-12 09:39:04,219 :: INFO <module> :: Batch 262: 262/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:04
# 2023-09-12 09:39:04,702 :: INFO <module> :: Batch 263: 263/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:04
# 2023-09-12 09:39:05,171 :: INFO <module> :: Batch 264: 264/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:05
# 2023-09-12 09:39:05,615 :: INFO <module> :: Batch 265: 265/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:05
# 2023-09-12 09:39:06,118 :: INFO <module> :: Batch 266: 266/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:06
# 2023-09-12 09:39:06,543 :: INFO <module> :: Batch 267: 267/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:06
# 2023-09-12 09:39:07,040 :: INFO <module> :: Batch 268: 268/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:07
# 2023-09-12 09:39:07,530 :: INFO <module> :: Batch 269: 269/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:07
# 2023-09-12 09:39:07,988 :: INFO <module> :: Batch 270: 270/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:07
# 2023-09-12 09:39:08,477 :: INFO <module> :: Batch 271: 271/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:08
# 2023-09-12 09:39:08,969 :: INFO <module> :: Batch 272: 272/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:08
# 2023-09-12 09:39:09,436 :: INFO <module> :: Batch 273: 273/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:09
# 2023-09-12 09:39:09,926 :: INFO <module> :: Batch 274: 274/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:09
# 2023-09-12 09:39:10,389 :: INFO <module> :: Batch 275: 275/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:10
# 2023-09-12 09:39:10,866 :: INFO <module> :: Batch 276: 276/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:10
# 2023-09-12 09:39:11,338 :: INFO <module> :: Batch 277: 277/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:11
# 2023-09-12 09:39:11,813 :: INFO <module> :: Batch 278: 278/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:11
# 2023-09-12 09:39:12,266 :: INFO <module> :: Batch 279: 279/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:12
# 2023-09-12 09:39:12,725 :: INFO <module> :: Batch 280: 280/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:12
# 2023-09-12 09:39:13,172 :: INFO <module> :: Batch 281: 281/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:13
# 2023-09-12 09:39:13,642 :: INFO <module> :: Batch 282: 282/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:13
# 2023-09-12 09:39:14,079 :: INFO <module> :: Batch 283: 283/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:14
# 2023-09-12 09:39:14,532 :: INFO <module> :: Batch 284: 284/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:14
# 2023-09-12 09:39:14,988 :: INFO <module> :: Batch 285: 285/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:14
# 2023-09-12 09:39:15,456 :: INFO <module> :: Batch 286: 286/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:15
# 2023-09-12 09:39:15,886 :: INFO <module> :: Batch 287: 287/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:15
# 2023-09-12 09:39:16,345 :: INFO <module> :: Batch 288: 288/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:16
# 2023-09-12 09:39:16,818 :: INFO <module> :: Batch 289: 289/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:16
# 2023-09-12 09:39:17,253 :: INFO <module> :: Batch 290: 290/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:17
# 2023-09-12 09:39:17,722 :: INFO <module> :: Batch 291: 291/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:17
# 2023-09-12 09:39:18,168 :: INFO <module> :: Batch 292: 292/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:18
# 2023-09-12 09:39:18,619 :: INFO <module> :: Batch 293: 293/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:18
# 2023-09-12 09:39:19,067 :: INFO <module> :: Batch 294: 294/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:19
# 2023-09-12 09:39:19,530 :: INFO <module> :: Batch 295: 295/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:19
# 2023-09-12 09:39:19,976 :: INFO <module> :: Batch 296: 296/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:19
# 2023-09-12 09:39:20,445 :: INFO <module> :: Batch 297: 297/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:20
# 2023-09-12 09:39:20,912 :: INFO <module> :: Batch 298: 298/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:20
# 2023-09-12 09:39:21,371 :: INFO <module> :: Batch 299: 299/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:21
# 2023-09-12 09:39:21,835 :: INFO <module> :: Batch 300: 300/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:21
# 2023-09-12 09:39:22,286 :: INFO <module> :: Batch 301: 301/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:22
# 2023-09-12 09:39:22,727 :: INFO <module> :: Batch 302: 302/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:22
# 2023-09-12 09:39:23,189 :: INFO <module> :: Batch 303: 303/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:23
# 2023-09-12 09:39:23,632 :: INFO <module> :: Batch 304: 304/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:23
# 2023-09-12 09:39:24,093 :: INFO <module> :: Batch 305: 305/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:24
# 2023-09-12 09:39:24,534 :: INFO <module> :: Batch 306: 306/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:24
# 2023-09-12 09:39:25,018 :: INFO <module> :: Batch 307: 307/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:25
# 2023-09-12 09:39:25,500 :: INFO <module> :: Batch 308: 308/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:25
# 2023-09-12 09:39:25,971 :: INFO <module> :: Batch 309: 309/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:25
# ...
# 2023-09-12 09:39:50,072 :: INFO <module> :: Batch 361: 361/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:50
# 2023-09-12 09:39:50,562 :: INFO <module> :: Batch 362: 362/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:50
# 2023-09-12 09:39:51,035 :: INFO <module> :: Batch 363: 363/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:51
# 2023-09-12 09:39:51,492 :: INFO <module> :: Batch 364: 364/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:51
# 2023-09-12 09:39:51,970 :: INFO <module> :: Batch 365: 365/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:51
# 2023-09-12 09:39:52,406 :: INFO <module> :: Batch 366: 366/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:52
# 2023-09-12 09:39:52,865 :: INFO <module> :: Batch 367: 367/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:52
# 2023-09-12 09:39:53,349 :: INFO <module> :: Batch 368: 368/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:53
# 2023-09-12 09:39:53,833 :: INFO <module> :: Batch 369: 369/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:53
# 2023-09-12 09:39:54,311 :: INFO <module> :: Batch 370: 370/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:54
# 2023-09-12 09:39:54,795 :: INFO <module> :: Batch 371: 371/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:54
# 2023-09-12 09:39:55,268 :: INFO <module> :: Batch 372: 372/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:55
# 2023-09-12 09:39:55,753 :: INFO <module> :: Batch 373: 373/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:55
# 2023-09-12 09:39:56,229 :: INFO <module> :: Batch 374: 374/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:56
# 2023-09-12 09:39:56,711 :: INFO <module> :: Batch 375: 375/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:56
# 2023-09-12 09:39:57,190 :: INFO <module> :: Batch 376: 376/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:57
# 2023-09-12 09:39:57,682 :: INFO <module> :: Batch 377: 377/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:57
# 2023-09-12 09:39:58,148 :: INFO <module> :: Batch 378: 378/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:58
# 2023-09-12 09:39:58,646 :: INFO <module> :: Batch 379: 379/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:58
# 2023-09-12 09:39:59,117 :: INFO <module> :: Batch 380: 380/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:59
# 2023-09-12 09:39:59,600 :: INFO <module> :: Batch 381: 381/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:39:59
# 2023-09-12 09:40:00,068 :: INFO <module> :: Batch 382: 382/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:00
# 2023-09-12 09:40:00,524 :: INFO <module> :: Batch 383: 383/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:00
# 2023-09-12 09:40:01,018 :: INFO <module> :: Batch 384: 384/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:01
# 2023-09-12 09:40:01,489 :: INFO <module> :: Batch 385: 385/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:01
# 2023-09-12 09:40:01,961 :: INFO <module> :: Batch 386: 386/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:01
# 2023-09-12 09:40:02,419 :: INFO <module> :: Batch 387: 387/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:02
# 2023-09-12 09:40:02,901 :: INFO <module> :: Batch 388: 388/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:02
# 2023-09-12 09:40:03,382 :: INFO <module> :: Batch 389: 389/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:03
# 2023-09-12 09:40:03,853 :: INFO <module> :: Batch 390: 390/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:03
# 2023-09-12 09:40:04,296 :: INFO <module> :: Batch 391: 391/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:04
# 2023-09-12 09:40:04,744 :: INFO <module> :: Batch 392: 392/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:04
# 2023-09-12 09:40:05,199 :: INFO <module> :: Batch 393: 393/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:05
# 2023-09-12 09:40:05,668 :: INFO <module> :: Batch 394: 394/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:05
# 2023-09-12 09:40:06,108 :: INFO <module> :: Batch 395: 395/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:06
# 2023-09-12 09:40:06,586 :: INFO <module> :: Batch 396: 396/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:06
# 2023-09-12 09:40:07,053 :: INFO <module> :: Batch 397: 397/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:07
# 2023-09-12 09:40:07,512 :: INFO <module> :: Batch 398: 398/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:07
# 2023-09-12 09:40:08,001 :: INFO <module> :: Batch 399: 399/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:08
# 2023-09-12 09:40:08,469 :: INFO <module> :: Batch 400: 400/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:08
# 2023-09-12 09:40:08,954 :: INFO <module> :: Batch 401: 401/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:08
# 2023-09-12 09:40:09,373 :: INFO <module> :: Batch 402: 402/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:09
# 2023-09-12 09:40:09,833 :: INFO <module> :: Batch 403: 403/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:09
# 2023-09-12 09:40:10,290 :: INFO <module> :: Batch 404: 404/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:10
# 2023-09-12 09:40:10,772 :: INFO <module> :: Batch 405: 405/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:10
# 2023-09-12 09:40:11,232 :: INFO <module> :: Batch 406: 406/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:11
# 2023-09-12 09:40:11,736 :: INFO <module> :: Batch 407: 407/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:11
# 2023-09-12 09:40:12,190 :: INFO <module> :: Batch 408: 408/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:12
# 2023-09-12 09:40:12,671 :: INFO <module> :: Batch 409: 409/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:12
# 2023-09-12 09:40:13,118 :: INFO <module> :: Batch 410: 410/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:13
# 2023-09-12 09:40:13,608 :: INFO <module> :: Batch 411: 411/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:13
# 2023-09-12 09:40:14,008 :: INFO <module> :: Batch 412: 412/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:14
# 2023-09-12 09:40:14,515 :: INFO <module> :: Batch 413: 413/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:14
# 2023-09-12 09:40:15,003 :: INFO <module> :: Batch 414: 414/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:15
# 2023-09-12 09:40:15,511 :: INFO <module> :: Batch 415: 415/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:15
# 2023-09-12 09:40:15,993 :: INFO <module> :: Batch 416: 416/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:15
# 2023-09-12 09:40:16,441 :: INFO <module> :: Batch 417: 417/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:16
# 2023-09-12 09:40:16,949 :: INFO <module> :: Batch 418: 418/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:16
# 2023-09-12 09:40:17,417 :: INFO <module> :: Batch 419: 419/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:17
# 2023-09-12 09:40:17,908 :: INFO <module> :: Batch 420: 420/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:17
# 2023-09-12 09:40:18,379 :: INFO <module> :: Batch 421: 421/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:18
# 2023-09-12 09:40:18,868 :: INFO <module> :: Batch 422: 422/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:18
# 2023-09-12 09:40:19,371 :: INFO <module> :: Batch 423: 423/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:19
# 2023-09-12 09:40:19,852 :: INFO <module> :: Batch 424: 424/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:19
# 2023-09-12 09:40:20,352 :: INFO <module> :: Batch 425: 425/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:20
# 2023-09-12 09:40:20,822 :: INFO <module> :: Batch 426: 426/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:20
# 2023-09-12 09:40:21,300 :: INFO <module> :: Batch 427: 427/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:21
# 2023-09-12 09:40:21,771 :: INFO <module> :: Batch 428: 428/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:21
# 2023-09-12 09:40:22,250 :: INFO <module> :: Batch 429: 429/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:22
# 2023-09-12 09:40:22,710 :: INFO <module> :: Batch 430: 430/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:22
# 2023-09-12 09:40:23,201 :: INFO <module> :: Batch 431: 431/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:23
# 2023-09-12 09:40:23,697 :: INFO <module> :: Batch 432: 432/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:23
# 2023-09-12 09:40:24,163 :: INFO <module> :: Batch 433: 433/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:24
# 2023-09-12 09:40:24,641 :: INFO <module> :: Batch 434: 434/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:24
# 2023-09-12 09:40:25,122 :: INFO <module> :: Batch 435: 435/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:25
# 2023-09-12 09:40:25,605 :: INFO <module> :: Batch 436: 436/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:25
# 2023-09-12 09:40:26,072 :: INFO <module> :: Batch 437: 437/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:26
# 2023-09-12 09:40:26,540 :: INFO <module> :: Batch 438: 438/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:26
# 2023-09-12 09:40:27,023 :: INFO <module> :: Batch 439: 439/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:27
# 2023-09-12 09:40:27,500 :: INFO <module> :: Batch 440: 440/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:27
# 2023-09-12 09:40:27,958 :: INFO <module> :: Batch 441: 441/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:27
# 2023-09-12 09:40:28,417 :: INFO <module> :: Batch 442: 442/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:28
# 2023-09-12 09:40:28,916 :: INFO <module> :: Batch 443: 443/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:28
# 2023-09-12 09:40:29,409 :: INFO <module> :: Batch 444: 444/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:29
# 2023-09-12 09:40:29,910 :: INFO <module> :: Batch 445: 445/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:29
# 2023-09-12 09:40:30,325 :: INFO <module> :: Batch 446: 446/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:30
# 2023-09-12 09:40:30,848 :: INFO <module> :: Batch 447: 447/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:30
# 2023-09-12 09:40:31,350 :: INFO <module> :: Batch 448: 448/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:31
# 2023-09-12 09:40:31,822 :: INFO <module> :: Batch 449: 449/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:31
# 2023-09-12 09:40:32,322 :: INFO <module> :: Batch 450: 450/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:32
# 2023-09-12 09:40:32,808 :: INFO <module> :: Batch 451: 451/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:32
# 2023-09-12 09:40:33,277 :: INFO <module> :: Batch 452: 452/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:33
# 2023-09-12 09:40:33,770 :: INFO <module> :: Batch 453: 453/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:33
# 2023-09-12 09:40:34,269 :: INFO <module> :: Batch 454: 454/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:34
# 2023-09-12 09:40:34,758 :: INFO <module> :: Batch 455: 455/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:34
# 2023-09-12 09:40:35,224 :: INFO <module> :: Batch 456: 456/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:35
# 2023-09-12 09:40:35,724 :: INFO <module> :: Batch 457: 457/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:35
# 2023-09-12 09:40:36,222 :: INFO <module> :: Batch 458: 458/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:36
# 2023-09-12 09:40:36,706 :: INFO <module> :: Batch 459: 459/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:36
# 2023-09-12 09:40:37,184 :: INFO <module> :: Batch 460: 460/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:37
# 2023-09-12 09:40:37,675 :: INFO <module> :: Batch 461: 461/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:37
# 2023-09-12 09:40:38,164 :: INFO <module> :: Batch 462: 462/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:38
# 2023-09-12 09:40:38,638 :: INFO <module> :: Batch 463: 463/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:38
# 2023-09-12 09:40:39,120 :: INFO <module> :: Batch 464: 464/464 images: torch.Size([1, 3, 640, 640]) masks: torch.Size([1, 640, 640]) 12/09/2023 09:40:39

# %% [markdown]
# # Execute the trained model (512x512)

# %%
from sourcecode.ORCA.orca_train import *
from sourcecode.ORCA.orca_dataloader_512x512 import *

import torchvision.transforms.functional as TF
from torchvision import transforms
from torchvision import utils
from datetime import datetime

from scipy import ndimage as nd
from skimage import measure

dataset_dir = "../../datasets/ORCA_512x512"
model_dir = "../../models"

batch_size = 1
patch_size = (512, 512)
color_model = "LAB"
dataloaders = create_dataloader(batch_size=batch_size, 
                                shuffle=False,
                                dataset_dir=dataset_dir,
                                color_model=color_model)

dataset_train_size = len(dataloaders['train'].dataset)
dataset_test_size = len(dataloaders['test'].dataset)


threshold_prob = 0.50
threshold_itc = 200/(0.243 * pow(2, 5))


# Checking for GPU availability
use_cuda=True
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") if use_cuda else "cpu"
logger.info('Runing on: {}'.format(device))

# loads our trained fcn model
trained_model_version = "ORCA__Size-512x512_Epoch-247_Images-80_Batch-1__no_augmentation"
trained_model_path="{}/{}".format(model_dir, '{}.pth'.format(trained_model_version))
model = load_checkpoint(file_path=trained_model_path, img_input_size=patch_size, use_cuda=use_cuda)
cont = 0
for batch_idx, (images, masks, fname, original_size) in enumerate(dataloaders['test']):
        
    X = Variable(images).to(device) if use_cuda else images
    logger.info('Batch {}: {}/{} images: {} masks: {} {}'.format(
                (batch_idx+1), 
                (batch_idx+1) * len(images), 
                len(dataloaders['test'].dataset),
                images.shape,
                masks.shape,
                datetime.now().strftime('%d/%m/%Y %H:%M:%S')))
    
    #X_numpy = X.cpu().numpy()
    y_hat = model(X).detach().cpu().squeeze(0)
    cls = "tumor"
    
    input_image = transforms.ToPILImage()(X.squeeze(0).cpu())
    output_mask = basic_threshold(y_hat[0].detach().cpu().numpy(), threshold=threshold_prob, output_type="uint8")

    predicted_labels = measure.label(output_mask, connectivity=2)
    output_mask = np.zeros((output_mask.shape[0], output_mask.shape[1]))
    labels = np.unique(predicted_labels)
    properties = measure.regionprops(predicted_labels)
    for lbl in range(1, (np.max(labels)+1)):
        major_axis_length = properties[lbl-1].major_axis_length
        if major_axis_length > threshold_itc:
            output_mask[predicted_labels == lbl] = 1

    input_image_rgb = lab_to_rgb(pil_to_np(input_image))
    roi_image = blend_image(np_to_pil(input_image_rgb), np_to_pil(output_mask), foreground='red', alpha=0.6, inverse=True)

    # results dir
    wsi_image_number = fname[0].split("_")[0] + "_" + fname[0].split("_")[1]
    patch_images_results_dir = "{}/results/{}/testing/{}/patch/{}x{}/{}".format(dataset_dir, trained_model_version, cls, patch_size[0], patch_size[1], wsi_image_number)
    results_output_dir = "{}/01-unet_result".format(patch_images_results_dir)
    if not os.path.exists(results_output_dir):
        os.makedirs(results_output_dir)
        
    results_roi_dir = "{}/02-roi".format(patch_images_results_dir)
    if not os.path.exists(results_roi_dir):
        os.makedirs(results_roi_dir)

    # save the results
    patch_img_name = fname[0]
    utils.save_image(y_hat[0], '{}/{}'.format(results_output_dir, patch_img_name))
    utils.save_image(TF.to_tensor(roi_image), '{}/{}'.format(results_roi_dir, patch_img_name))
# Out:
# 2021-06-03 17:22:47,669 :: INFO load_dataset :: [training] ../../datasets/ORCA_512x512/training
# 2021-06-03 17:22:47,673 :: INFO load_dataset :: [training] ../../datasets/ORCA_512x512/training
# 2021-06-03 17:22:47,675 :: INFO load_dataset :: [testing] ../../datasets/ORCA_512x512/testing
# 2021-06-03 17:22:47,678 :: INFO create_dataloader :: Train images: 100 augmentation: random
# 2021-06-03 17:22:47,679 :: INFO create_dataloader :: Test images: 100 augmentation: no_augmentation
# 2021-06-03 17:22:47,679 :: INFO <module> :: Runing on: cuda
# 2021-06-03 17:23:00,398 :: INFO load_checkpoint :: 	 Model loaded on: cuda / 3 / 1 / (512, 512) -> ../../models/ORCA__Size-512x512_Epoch-247_Images-80_Batch-1__no_augmentation.pth
# 2021-06-03 17:23:00,462 :: INFO transform :: Epoch: '1' augmentation no_augmentation None
# 2021-06-03 17:23:00,483 :: INFO <module> :: Batch 1: 1/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:00
# 2021-06-03 17:23:01,004 :: INFO <module> :: Batch 2: 2/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:01
# 2021-06-03 17:23:01,533 :: INFO <module> :: Batch 3: 3/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:01
# 2021-06-03 17:23:02,060 :: INFO <module> :: Batch 4: 4/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:02
# 2021-06-03 17:23:02,578 :: INFO <module> :: Batch 5: 5/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:02
# 2021-06-03 17:23:03,057 :: INFO <module> :: Batch 6: 6/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:03
# 2021-06-03 17:23:03,569 :: INFO <module> :: Batch 7: 7/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:03
# 2021-06-03 17:23:04,066 :: INFO <module> :: Batch 8: 8/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:04
# 2021-06-03 17:23:04,572 :: INFO <module> :: Batch 9: 9/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:04
# 2021-06-03 17:23:05,119 :: INFO <module> :: Batch 10: 10/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:05
# 2021-06-03 17:23:05,642 :: INFO <module> :: Batch 11: 11/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:05
# 2021-06-03 17:23:06,154 :: INFO <module> :: Batch 12: 12/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:06
# 2021-06-03 17:23:06,660 :: INFO <module> :: Batch 13: 13/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:06
# 2021-06-03 17:23:07,220 :: INFO <module> :: Batch 14: 14/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:07
# 2021-06-03 17:23:07,730 :: INFO <module> :: Batch 15: 15/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:07
# 2021-06-03 17:23:08,253 :: INFO <module> :: Batch 16: 16/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:08
# 2021-06-03 17:23:08,909 :: INFO <module> :: Batch 17: 17/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:08
# 2021-06-03 17:23:09,402 :: INFO <module> :: Batch 18: 18/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:09
# 2021-06-03 17:23:09,927 :: INFO <module> :: Batch 19: 19/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:09
# 2021-06-03 17:23:10,490 :: INFO <module> :: Batch 20: 20/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:10
# 2021-06-03 17:23:11,122 :: INFO <module> :: Batch 21: 21/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:11
# 2021-06-03 17:23:11,605 :: INFO <module> :: Batch 22: 22/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:11
# 2021-06-03 17:23:12,143 :: INFO <module> :: Batch 23: 23/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:12
# 2021-06-03 17:23:12,715 :: INFO <module> :: Batch 24: 24/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:12
# 2021-06-03 17:23:13,259 :: INFO <module> :: Batch 25: 25/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:13
# 2021-06-03 17:23:13,782 :: INFO <module> :: Batch 26: 26/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:13
# 2021-06-03 17:23:14,253 :: INFO <module> :: Batch 27: 27/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:14
# 2021-06-03 17:23:14,744 :: INFO <module> :: Batch 28: 28/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:14
# 2021-06-03 17:23:15,301 :: INFO <module> :: Batch 29: 29/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:15
# 2021-06-03 17:23:15,826 :: INFO <module> :: Batch 30: 30/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:15
# 2021-06-03 17:23:16,353 :: INFO <module> :: Batch 31: 31/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:16
# 2021-06-03 17:23:17,074 :: INFO <module> :: Batch 32: 32/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:17
# 2021-06-03 17:23:17,742 :: INFO <module> :: Batch 33: 33/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:17
# 2021-06-03 17:23:18,319 :: INFO <module> :: Batch 34: 34/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:18
# 2021-06-03 17:23:18,818 :: INFO <module> :: Batch 35: 35/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:18
# 2021-06-03 17:23:19,458 :: INFO <module> :: Batch 36: 36/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:19
# 2021-06-03 17:23:20,107 :: INFO <module> :: Batch 37: 37/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:20
# 2021-06-03 17:23:20,699 :: INFO <module> :: Batch 38: 38/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:20
# 2021-06-03 17:23:21,230 :: INFO <module> :: Batch 39: 39/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:21
# 2021-06-03 17:23:21,702 :: INFO <module> :: Batch 40: 40/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:21
# 2021-06-03 17:23:22,164 :: INFO <module> :: Batch 41: 41/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:22
# 2021-06-03 17:23:22,648 :: INFO <module> :: Batch 42: 42/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:22
# 2021-06-03 17:23:23,137 :: INFO <module> :: Batch 43: 43/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:23
# 2021-06-03 17:23:23,640 :: INFO <module> :: Batch 44: 44/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:23
# 2021-06-03 17:23:24,144 :: INFO <module> :: Batch 45: 45/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:24
# 2021-06-03 17:23:24,641 :: INFO <module> :: Batch 46: 46/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:24
# 2021-06-03 17:23:25,137 :: INFO <module> :: Batch 47: 47/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:25
# 2021-06-03 17:23:25,666 :: INFO <module> :: Batch 48: 48/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:25
# 2021-06-03 17:23:26,157 :: INFO <module> :: Batch 49: 49/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:26
# 2021-06-03 17:23:26,594 :: INFO <module> :: Batch 50: 50/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:26
# 2021-06-03 17:23:27,073 :: INFO <module> :: Batch 51: 51/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:27
# 2021-06-03 17:23:27,546 :: INFO <module> :: Batch 52: 52/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:27
# 2021-06-03 17:23:28,019 :: INFO <module> :: Batch 53: 53/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:28
# 2021-06-03 17:23:28,498 :: INFO <module> :: Batch 54: 54/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:28
# 2021-06-03 17:23:28,984 :: INFO <module> :: Batch 55: 55/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:28
# 2021-06-03 17:23:29,481 :: INFO <module> :: Batch 56: 56/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:29
# 2021-06-03 17:23:29,963 :: INFO <module> :: Batch 57: 57/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:29
# 2021-06-03 17:23:30,503 :: INFO <module> :: Batch 58: 58/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:30
# 2021-06-03 17:23:31,010 :: INFO <module> :: Batch 59: 59/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:31
# 2021-06-03 17:23:31,501 :: INFO <module> :: Batch 60: 60/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:31
# 2021-06-03 17:23:31,994 :: INFO <module> :: Batch 61: 61/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:31
# 2021-06-03 17:23:32,568 :: INFO <module> :: Batch 62: 62/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:32
# 2021-06-03 17:23:33,118 :: INFO <module> :: Batch 63: 63/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:33
# 2021-06-03 17:23:33,684 :: INFO <module> :: Batch 64: 64/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:33
# 2021-06-03 17:23:34,200 :: INFO <module> :: Batch 65: 65/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:34
# 2021-06-03 17:23:34,685 :: INFO <module> :: Batch 66: 66/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:34
# 2021-06-03 17:23:35,170 :: INFO <module> :: Batch 67: 67/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:35
# 2021-06-03 17:23:35,822 :: INFO <module> :: Batch 68: 68/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:35
# 2021-06-03 17:23:36,455 :: INFO <module> :: Batch 69: 69/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:36
# 2021-06-03 17:23:36,973 :: INFO <module> :: Batch 70: 70/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:36
# 2021-06-03 17:23:37,486 :: INFO <module> :: Batch 71: 71/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:37
# 2021-06-03 17:23:38,141 :: INFO <module> :: Batch 72: 72/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:38
# 2021-06-03 17:23:38,749 :: INFO <module> :: Batch 73: 73/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:38
# 2021-06-03 17:23:39,274 :: INFO <module> :: Batch 74: 74/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:39
# 2021-06-03 17:23:39,800 :: INFO <module> :: Batch 75: 75/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:39
# 2021-06-03 17:23:40,365 :: INFO <module> :: Batch 76: 76/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:40
# 2021-06-03 17:23:41,878 :: INFO <module> :: Batch 77: 77/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:41
# 2021-06-03 17:23:42,467 :: INFO <module> :: Batch 78: 78/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:42
# 2021-06-03 17:23:43,016 :: INFO <module> :: Batch 79: 79/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:43
# 2021-06-03 17:23:43,515 :: INFO <module> :: Batch 80: 80/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:43
# 2021-06-03 17:23:44,099 :: INFO <module> :: Batch 81: 81/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:44
# 2021-06-03 17:23:44,599 :: INFO <module> :: Batch 82: 82/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:44
# 2021-06-03 17:23:45,155 :: INFO <module> :: Batch 83: 83/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:45
# 2021-06-03 17:23:45,727 :: INFO <module> :: Batch 84: 84/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:45
# 2021-06-03 17:23:46,309 :: INFO <module> :: Batch 85: 85/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:46
# 2021-06-03 17:23:46,793 :: INFO <module> :: Batch 86: 86/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:46
# 2021-06-03 17:23:47,287 :: INFO <module> :: Batch 87: 87/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:47
# 2021-06-03 17:23:47,877 :: INFO <module> :: Batch 88: 88/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:47
# 2021-06-03 17:23:48,351 :: INFO <module> :: Batch 89: 89/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:48
# 2021-06-03 17:23:48,834 :: INFO <module> :: Batch 90: 90/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:48
# 2021-06-03 17:23:49,412 :: INFO <module> :: Batch 91: 91/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:49
# 2021-06-03 17:23:50,240 :: INFO <module> :: Batch 92: 92/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:50
# 2021-06-03 17:23:50,735 :: INFO <module> :: Batch 93: 93/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:50
# 2021-06-03 17:23:51,344 :: INFO <module> :: Batch 94: 94/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:51
# 2021-06-03 17:23:51,943 :: INFO <module> :: Batch 95: 95/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:51
# 2021-06-03 17:23:52,521 :: INFO <module> :: Batch 96: 96/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:52
# 2021-06-03 17:23:53,067 :: INFO <module> :: Batch 97: 97/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:53
# 2021-06-03 17:23:53,720 :: INFO <module> :: Batch 98: 98/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:53
# 2021-06-03 17:23:54,292 :: INFO <module> :: Batch 99: 99/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:54
# 2021-06-03 17:23:54,965 :: INFO <module> :: Batch 100: 100/100 images: torch.Size([1, 3, 512, 512]) masks: torch.Size([1, 512, 512]) 03/06/2021 17:23:54
